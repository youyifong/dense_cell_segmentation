# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division

import datetime
import os
import numpy as np
from timeit import default_timer
import ssl 
ssl._create_default_https_context = ssl._create_unverified_context
import syotil
from skimage import io
import glob
from matplotlib import pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.losses import MSE
from tensorflow.python.data import Dataset
from tensorflow.keras.optimizers import SGD, Adam

from deepcell import losses
from deepcell import image_generators
from deepcell.utils import train_utils
from deepcell.utils import tracking_utils
from deepcell.utils.data_utils import get_data
from deepcell.utils.train_utils import rate_scheduler
from deepcell.utils.train_utils import get_callbacks
from deepcell.utils.train_utils import count_gpus
from deepcell.applications import NuclearSegmentation

# %%
# read image files
imgfiles = glob.glob('images/training/*_img.png')
print(imgfiles)

# show one file
img=io.imread(imgfiles[0])
print(img.shape)
im=img[:,:,0]
io.imshow(im)
plt.show()

imgs = [io.imread(imgfile)[:,:,0] for imgfile in imgfiles]

X_train = tf.stack(imgs)
X_train = np.expand_dims(X_train, axis=-1)
print(X_train.shape)

# read mask files
maskfiles = glob.glob('images/training/*_masks.png')
img=io.imread(maskfiles[0])
print(img.shape)
im=img
io.imshow(im)
plt.show()

masks = [io.imread(imgfile) for imgfile in maskfiles]

y_train = tf.stack(masks)
y_train = np.expand_dims(y_train, axis=-1)
print(y_train.shape)

np.savez("K_training_data", X=X_train, y=y_train) # objects to save need to be key value pairs

test_size=.2
seed=0
train_dict, test_dict = get_data("K_training_data.npz", test_size=test_size, seed=seed)
# Out:
# ['images/training/M872956_JML_Position9_CD3_train_img.png', 'images/training/M872956_JML_Position8_CD3_train_img.png', 'images/training/M926910_CFL_Position7_CD3_train_img.png', 'images/training/M926910_CFL_Position13_CD3_train_img.png', 'images/training/M872956_JML_Position8_CD8_train_img.png', 'images/training/M872956_JML_Position10_CD3_train_img.png', 'images/training/M872956_JML_Position8_CD4_train_img.png']
# (1040, 1159, 3)
# 2022-10-10 12:54:15.823942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10429 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:5e:00.0, compute capability: 6.1
# /app/software/scikit-image/0.19.1-foss-2021b/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# (7, 1040, 1159, 1)
# (1040, 1159)
# (7, 1040, 1159, 1)

# %%
# Training model
# One-channel
MODEL_PATH = ('https://deepcell-data.s3-us-west-1.amazonaws.com/'
              'saved-models/NuclearSegmentation-5.tar.gz')
MODEL_HASH = 'c3667ffbe08035c9cb69ed882e4a49d7'
archive_path = tf.keras.utils.get_file(
                'NuclearSegmentation.tgz', MODEL_PATH,
                file_hash=MODEL_HASH,
                extract=True, cache_subdir='models')
model_path = os.path.splitext(archive_path)[0]
print(model_path)
# Out:
# /home/yfong/.keras/models/NuclearSegmentation

# %%
new_model = tf.keras.models.load_model(model_path)

import copy
pretrained_model = copy.deepcopy(new_model) # this copy will not be trained
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2022-10-10 12:55:25.150291: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ram://62d825ce-81f4-4006-85a3-2bd357519fd1/assets
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
[(layer.output_shape, layer.name) for layer in filter(lambda x: x.name.startswith('semantic_'), new_model.layers)]
# Out:
# [((None, 512, 512, 1), 'semantic_0'), ((None, 512, 512, 1), 'semantic_1')]

# %%
transforms = ['inner-distance', 'outer-distance']
transforms_kwargs = {'outer-distance': {'erosion_width': 0}}
#                      'inner-distance': {'erosion_width': 1, 'alpha': 'auto'}},

model_name = 'nuclear20221010'
n_epoch = 100
optimizer = Adam(learning_rate=1e-4, clipnorm=0.001)
lr_sched = rate_scheduler(lr=1e-4, decay=0.99)
batch_size = 1 # 8
min_objects = 0  # throw out images with fewer than this many objects
seed=0
model_name

datagen = image_generators.CroppingDataGenerator(
    rotation_range=180,
    shear_range=0,
    zoom_range=(0.7, 1/0.7),
    horizontal_flip=True,
    vertical_flip=True,
    #crop_size=(256, 256)) # generate error
    crop_size=(512, 512)) 

datagen_val = image_generators.SemanticDataGenerator(
    rotation_range=0,
    shear_range=0,
    zoom_range=0,
    horizontal_flip=0,
    vertical_flip=0)
    
train_data = datagen.flow(
    train_dict,
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    test_dict,
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

# Define loss (create a dictionary of losses for each semantic head)

def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * losses.weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss

loss = {}

# Give losses for all of the semantic heads
for layer in new_model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)

new_model.compile(loss=loss, optimizer=optimizer)

# %%
MODEL_DIR = os.path.join('models')
LOG_DIR = os.path.join('logs')
if not os.path.exists(MODEL_DIR): os.mkdir(MODEL_DIR)
if not os.path.exists(LOG_DIR): os.mkdir(LOG_DIR)    
model_path = os.path.join(MODEL_DIR, '{}.h5'.format(model_name))
loss_path = os.path.join(MODEL_DIR, '{}.npz'.format(model_name))

# %%
train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    tensorboard_log_dir=LOG_DIR,
    save_weights_only=True,
    #save_weights_only=num_gpus >= 2,
    #monitor='val_loss',
    monitor='loss', # training loss
    verbose=1)

start = default_timer()
loss_history = new_model.fit_generator(
    train_data,
    steps_per_epoch=train_data.y.shape[0] // batch_size,
    epochs=n_epoch,
    #validation_data=val_data,
    #validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
training_time = default_timer() - start
print('Training time: ', training_time, 'seconds.')
# Out:
# /tmp/ipykernel_17899/4273487405.py:12: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   loss_history = new_model.fit_generator(
# Epoch 1/100
# 2022-10-10 12:57:02.047218: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8202
# 5/5 [==============================] - ETA: 0s - loss: 0.0665 - semantic_0_loss: 0.0243 - semantic_1_loss: 0.0422
# Epoch 00001: loss improved from inf to 0.06649, saving model to models/nuclear20221010.h5
# 5/5 [==============================] - 34s 3s/step - loss: 0.0665 - semantic_0_loss: 0.0243 - semantic_1_loss: 0.0422 - lr: 1.0000e-04
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0863 - semantic_0_loss: 0.0299 - semantic_1_loss: 0.0564
# Epoch 00002: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0863 - semantic_0_loss: 0.0299 - semantic_1_loss: 0.0564 - lr: 9.9000e-05
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0805 - semantic_0_loss: 0.0284 - semantic_1_loss: 0.0522
# Epoch 00003: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0805 - semantic_0_loss: 0.0284 - semantic_1_loss: 0.0522 - lr: 9.8010e-05
# Epoch 4/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0729 - semantic_0_loss: 0.0256 - semantic_1_loss: 0.0473
# Epoch 00004: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0729 - semantic_0_loss: 0.0256 - semantic_1_loss: 0.0473 - lr: 9.7030e-05
# Epoch 5/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0679 - semantic_0_loss: 0.0240 - semantic_1_loss: 0.0439
# Epoch 00005: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0679 - semantic_0_loss: 0.0240 - semantic_1_loss: 0.0439 - lr: 9.6060e-05
# Epoch 6/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0689 - semantic_0_loss: 0.0244 - semantic_1_loss: 0.0445
# Epoch 00006: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0689 - semantic_0_loss: 0.0244 - semantic_1_loss: 0.0445 - lr: 9.5099e-05
# Epoch 7/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0778 - semantic_0_loss: 0.0276 - semantic_1_loss: 0.0502
# Epoch 00007: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0778 - semantic_0_loss: 0.0276 - semantic_1_loss: 0.0502 - lr: 9.4148e-05
# Epoch 8/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0795 - semantic_0_loss: 0.0289 - semantic_1_loss: 0.0506
# Epoch 00008: loss did not improve from 0.06649
# 5/5 [==============================] - 11s 2s/step - loss: 0.0795 - semantic_0_loss: 0.0289 - semantic_1_loss: 0.0506 - lr: 9.3207e-05
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0620 - semantic_0_loss: 0.0222 - semantic_1_loss: 0.0398
# Epoch 00009: loss improved from 0.06649 to 0.06203, saving model to models/nuclear20221010.h5
# 5/5 [==============================] - 12s 2s/step - loss: 0.0620 - semantic_0_loss: 0.0222 - semantic_1_loss: 0.0398 - lr: 9.2274e-05
# Epoch 10/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0608 - semantic_0_loss: 0.0209 - semantic_1_loss: 0.0399
# Epoch 00010: loss improved from 0.06203 to 0.06085, saving model to models/nuclear20221010.h5
# 5/5 [==============================] - 12s 2s/step - loss: 0.0608 - semantic_0_loss: 0.0209 - semantic_1_loss: 0.0399 - lr: 9.1352e-05
# Epoch 11/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0741 - semantic_0_loss: 0.0258 - semantic_1_loss: 0.0484
# Epoch 00011: loss did not improve from 0.06085
# 5/5 [==============================] - 11s 2s/step - loss: 0.0741 - semantic_0_loss: 0.0258 - semantic_1_loss: 0.0484 - lr: 9.0438e-05
# Epoch 12/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0811 - semantic_0_loss: 0.0283 - semantic_1_loss: 0.0528
# Epoch 00012: loss did not improve from 0.06085
# 5/5 [==============================] - 11s 2s/step - loss: 0.0811 - semantic_0_loss: 0.0283 - semantic_1_loss: 0.0528 - lr: 8.9534e-05
# Epoch 13/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0776 - semantic_0_loss: 0.0279 - semantic_1_loss: 0.0497
# Epoch 00013: loss did not improve from 0.06085
# 5/5 [==============================] - 11s 2s/step - loss: 0.0776 - semantic_0_loss: 0.0279 - semantic_1_loss: 0.0497 - lr: 8.8638e-05
# Epoch 14/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0810 - semantic_0_loss: 0.0283 - semantic_1_loss: 0.0527
# Epoch 00014: loss did not improve from 0.06085
# 5/5 [==============================] - 11s 2s/step - loss: 0.0810 - semantic_0_loss: 0.0283 - semantic_1_loss: 0.0527 - lr: 8.7752e-05
# Epoch 15/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0718 - semantic_0_loss: 0.0246 - semantic_1_loss: 0.0472
# Epoch 00015: loss did not improve from 0.06085
# 5/5 [==============================] - 11s 2s/step - loss: 0.0718 - semantic_0_loss: 0.0246 - semantic_1_loss: 0.0472 - lr: 8.6875e-05
# Epoch 16/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0691 - semantic_0_loss: 0.0246 - semantic_1_loss: 0.0444
# Epoch 00016: loss did not improve from 0.06085
# 5/5 [==============================] - 11s 2s/step - loss: 0.0691 - semantic_0_loss: 0.0246 - semantic_1_loss: 0.0444 - lr: 8.6006e-05
# Epoch 17/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0524 - semantic_0_loss: 0.0187 - semantic_1_loss: 0.0337
# Epoch 00017: loss improved from 0.06085 to 0.05241, saving model to models/nuclear20221010.h5
# 5/5 [==============================] - 14s 3s/step - loss: 0.0524 - semantic_0_loss: 0.0187 - semantic_1_loss: 0.0337 - lr: 8.5146e-05
# Epoch 18/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0689 - semantic_0_loss: 0.0245 - semantic_1_loss: 0.0444
# Epoch 00018: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0689 - semantic_0_loss: 0.0245 - semantic_1_loss: 0.0444 - lr: 8.4294e-05
# Epoch 19/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0893 - semantic_0_loss: 0.0317 - semantic_1_loss: 0.0575
# Epoch 00019: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0893 - semantic_0_loss: 0.0317 - semantic_1_loss: 0.0575 - lr: 8.3451e-05
# Epoch 20/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0762 - semantic_0_loss: 0.0269 - semantic_1_loss: 0.0493
# Epoch 00020: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0762 - semantic_0_loss: 0.0269 - semantic_1_loss: 0.0493 - lr: 8.2617e-05
# Epoch 21/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0673 - semantic_0_loss: 0.0242 - semantic_1_loss: 0.0431
# Epoch 00021: loss did not improve from 0.05241
# 5/5 [==============================] - 14s 3s/step - loss: 0.0673 - semantic_0_loss: 0.0242 - semantic_1_loss: 0.0431 - lr: 8.1791e-05
# Epoch 22/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0792 - semantic_0_loss: 0.0281 - semantic_1_loss: 0.0510
# Epoch 00022: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0792 - semantic_0_loss: 0.0281 - semantic_1_loss: 0.0510 - lr: 8.0973e-05
# Epoch 23/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0622 - semantic_0_loss: 0.0213 - semantic_1_loss: 0.0409
# Epoch 00023: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0622 - semantic_0_loss: 0.0213 - semantic_1_loss: 0.0409 - lr: 8.0163e-05
# Epoch 24/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0786 - semantic_0_loss: 0.0275 - semantic_1_loss: 0.0511
# Epoch 00024: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0786 - semantic_0_loss: 0.0275 - semantic_1_loss: 0.0511 - lr: 7.9361e-05
# Epoch 25/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0676 - semantic_0_loss: 0.0245 - semantic_1_loss: 0.0431
# Epoch 00025: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0676 - semantic_0_loss: 0.0245 - semantic_1_loss: 0.0431 - lr: 7.8568e-05
# Epoch 26/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0745 - semantic_0_loss: 0.0262 - semantic_1_loss: 0.0483
# Epoch 00026: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0745 - semantic_0_loss: 0.0262 - semantic_1_loss: 0.0483 - lr: 7.7782e-05
# Epoch 27/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0799 - semantic_0_loss: 0.0272 - semantic_1_loss: 0.0527
# Epoch 00027: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0799 - semantic_0_loss: 0.0272 - semantic_1_loss: 0.0527 - lr: 7.7004e-05
# Epoch 28/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0664 - semantic_0_loss: 0.0236 - semantic_1_loss: 0.0428
# Epoch 00028: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0664 - semantic_0_loss: 0.0236 - semantic_1_loss: 0.0428 - lr: 7.6234e-05
# Epoch 29/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0659 - semantic_0_loss: 0.0230 - semantic_1_loss: 0.0428
# Epoch 00029: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0659 - semantic_0_loss: 0.0230 - semantic_1_loss: 0.0428 - lr: 7.5472e-05
# Epoch 30/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0572 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0368
# Epoch 00030: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0572 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0368 - lr: 7.4717e-05
# Epoch 31/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0774 - semantic_0_loss: 0.0276 - semantic_1_loss: 0.0498
# Epoch 00031: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0774 - semantic_0_loss: 0.0276 - semantic_1_loss: 0.0498 - lr: 7.3970e-05
# Epoch 32/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0637 - semantic_0_loss: 0.0228 - semantic_1_loss: 0.0409
# Epoch 00032: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0637 - semantic_0_loss: 0.0228 - semantic_1_loss: 0.0409 - lr: 7.3230e-05
# Epoch 33/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0613 - semantic_0_loss: 0.0216 - semantic_1_loss: 0.0398
# Epoch 00033: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0613 - semantic_0_loss: 0.0216 - semantic_1_loss: 0.0398 - lr: 7.2498e-05
# Epoch 34/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0748 - semantic_0_loss: 0.0282 - semantic_1_loss: 0.0466
# Epoch 00034: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0748 - semantic_0_loss: 0.0282 - semantic_1_loss: 0.0466 - lr: 7.1773e-05
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0660 - semantic_0_loss: 0.0235 - semantic_1_loss: 0.0425
# Epoch 00035: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0660 - semantic_0_loss: 0.0235 - semantic_1_loss: 0.0425 - lr: 7.1055e-05
# Epoch 36/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0664 - semantic_0_loss: 0.0235 - semantic_1_loss: 0.0429
# Epoch 00036: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0664 - semantic_0_loss: 0.0235 - semantic_1_loss: 0.0429 - lr: 7.0345e-05
# Epoch 37/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0799 - semantic_0_loss: 0.0276 - semantic_1_loss: 0.0522
# Epoch 00037: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0799 - semantic_0_loss: 0.0276 - semantic_1_loss: 0.0522 - lr: 6.9641e-05
# Epoch 38/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0686 - semantic_0_loss: 0.0245 - semantic_1_loss: 0.0441
# Epoch 00038: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0686 - semantic_0_loss: 0.0245 - semantic_1_loss: 0.0441 - lr: 6.8945e-05
# Epoch 39/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0721 - semantic_0_loss: 0.0258 - semantic_1_loss: 0.0463
# Epoch 00039: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0721 - semantic_0_loss: 0.0258 - semantic_1_loss: 0.0463 - lr: 6.8255e-05
# Epoch 40/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0711 - semantic_0_loss: 0.0248 - semantic_1_loss: 0.0463
# Epoch 00040: loss did not improve from 0.05241
# 5/5 [==============================] - 14s 3s/step - loss: 0.0711 - semantic_0_loss: 0.0248 - semantic_1_loss: 0.0463 - lr: 6.7573e-05
# Epoch 41/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0619 - semantic_0_loss: 0.0229 - semantic_1_loss: 0.0390
# Epoch 00041: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0619 - semantic_0_loss: 0.0229 - semantic_1_loss: 0.0390 - lr: 6.6897e-05
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0648 - semantic_0_loss: 0.0230 - semantic_1_loss: 0.0419
# Epoch 00042: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0648 - semantic_0_loss: 0.0230 - semantic_1_loss: 0.0419 - lr: 6.6228e-05
# Epoch 43/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0888 - semantic_0_loss: 0.0313 - semantic_1_loss: 0.0575
# Epoch 00043: loss did not improve from 0.05241
# 5/5 [==============================] - 10s 2s/step - loss: 0.0888 - semantic_0_loss: 0.0313 - semantic_1_loss: 0.0575 - lr: 6.5566e-05
# Epoch 44/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0562 - semantic_0_loss: 0.0207 - semantic_1_loss: 0.0356
# Epoch 00044: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0562 - semantic_0_loss: 0.0207 - semantic_1_loss: 0.0356 - lr: 6.4910e-05
# Epoch 45/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0667 - semantic_0_loss: 0.0231 - semantic_1_loss: 0.0436
# Epoch 00045: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0667 - semantic_0_loss: 0.0231 - semantic_1_loss: 0.0436 - lr: 6.4261e-05
# Epoch 46/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0753 - semantic_0_loss: 0.0279 - semantic_1_loss: 0.0473
# Epoch 00046: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0753 - semantic_0_loss: 0.0279 - semantic_1_loss: 0.0473 - lr: 6.3619e-05
# Epoch 47/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0755 - semantic_0_loss: 0.0272 - semantic_1_loss: 0.0483
# Epoch 00047: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0755 - semantic_0_loss: 0.0272 - semantic_1_loss: 0.0483 - lr: 6.2982e-05
# Epoch 48/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0694 - semantic_0_loss: 0.0248 - semantic_1_loss: 0.0446
# Epoch 00048: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0694 - semantic_0_loss: 0.0248 - semantic_1_loss: 0.0446 - lr: 6.2353e-05
# Epoch 49/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0583 - semantic_0_loss: 0.0211 - semantic_1_loss: 0.0372
# Epoch 00049: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0583 - semantic_0_loss: 0.0211 - semantic_1_loss: 0.0372 - lr: 6.1729e-05
# Epoch 50/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0625 - semantic_0_loss: 0.0213 - semantic_1_loss: 0.0412
# Epoch 00050: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0625 - semantic_0_loss: 0.0213 - semantic_1_loss: 0.0412 - lr: 6.1112e-05
# Epoch 51/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0699 - semantic_0_loss: 0.0258 - semantic_1_loss: 0.0442
# Epoch 00051: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0699 - semantic_0_loss: 0.0258 - semantic_1_loss: 0.0442 - lr: 6.0501e-05
# Epoch 52/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0730 - semantic_0_loss: 0.0267 - semantic_1_loss: 0.0463
# Epoch 00052: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0730 - semantic_0_loss: 0.0267 - semantic_1_loss: 0.0463 - lr: 5.9896e-05
# Epoch 53/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0688 - semantic_0_loss: 0.0240 - semantic_1_loss: 0.0448
# Epoch 00053: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0688 - semantic_0_loss: 0.0240 - semantic_1_loss: 0.0448 - lr: 5.9297e-05
# Epoch 54/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0614 - semantic_0_loss: 0.0220 - semantic_1_loss: 0.0394
# Epoch 00054: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0614 - semantic_0_loss: 0.0220 - semantic_1_loss: 0.0394 - lr: 5.8704e-05
# Epoch 55/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0711 - semantic_0_loss: 0.0252 - semantic_1_loss: 0.0458
# Epoch 00055: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0711 - semantic_0_loss: 0.0252 - semantic_1_loss: 0.0458 - lr: 5.8117e-05
# Epoch 56/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0715 - semantic_0_loss: 0.0257 - semantic_1_loss: 0.0458
# Epoch 00056: loss did not improve from 0.05241
# 5/5 [==============================] - 10s 2s/step - loss: 0.0715 - semantic_0_loss: 0.0257 - semantic_1_loss: 0.0458 - lr: 5.7535e-05
# Epoch 57/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0639 - semantic_0_loss: 0.0230 - semantic_1_loss: 0.0409
# Epoch 00057: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0639 - semantic_0_loss: 0.0230 - semantic_1_loss: 0.0409 - lr: 5.6960e-05
# Epoch 58/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0808 - semantic_0_loss: 0.0280 - semantic_1_loss: 0.0528
# Epoch 00058: loss did not improve from 0.05241
# 5/5 [==============================] - 13s 3s/step - loss: 0.0808 - semantic_0_loss: 0.0280 - semantic_1_loss: 0.0528 - lr: 5.6391e-05
# Epoch 59/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0696 - semantic_0_loss: 0.0237 - semantic_1_loss: 0.0459
# Epoch 00059: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0696 - semantic_0_loss: 0.0237 - semantic_1_loss: 0.0459 - lr: 5.5827e-05
# Epoch 60/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0591 - semantic_0_loss: 0.0208 - semantic_1_loss: 0.0382
# Epoch 00060: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0591 - semantic_0_loss: 0.0208 - semantic_1_loss: 0.0382 - lr: 5.5268e-05
# Epoch 61/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0746 - semantic_0_loss: 0.0267 - semantic_1_loss: 0.0479
# Epoch 00061: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0746 - semantic_0_loss: 0.0267 - semantic_1_loss: 0.0479 - lr: 5.4716e-05
# Epoch 62/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0556 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0351
# Epoch 00062: loss did not improve from 0.05241
# 5/5 [==============================] - 11s 2s/step - loss: 0.0556 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0351 - lr: 5.4169e-05
# Epoch 63/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0510 - semantic_0_loss: 0.0179 - semantic_1_loss: 0.0331
# Epoch 00063: loss improved from 0.05241 to 0.05101, saving model to models/nuclear20221010.h5
# 5/5 [==============================] - 12s 2s/step - loss: 0.0510 - semantic_0_loss: 0.0179 - semantic_1_loss: 0.0331 - lr: 5.3627e-05
# Epoch 64/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0860 - semantic_0_loss: 0.0306 - semantic_1_loss: 0.0554
# Epoch 00064: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0860 - semantic_0_loss: 0.0306 - semantic_1_loss: 0.0554 - lr: 5.3091e-05
# Epoch 65/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0591 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0387
# Epoch 00065: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0591 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0387 - lr: 5.2560e-05
# Epoch 66/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0708 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0454
# Epoch 00066: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0708 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0454 - lr: 5.2034e-05
# Epoch 67/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0715 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0461
# Epoch 00067: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0715 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0461 - lr: 5.1514e-05
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0581 - semantic_0_loss: 0.0209 - semantic_1_loss: 0.0372
# Epoch 00068: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0581 - semantic_0_loss: 0.0209 - semantic_1_loss: 0.0372 - lr: 5.0999e-05
# Epoch 69/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0793 - semantic_0_loss: 0.0285 - semantic_1_loss: 0.0508
# Epoch 00069: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0793 - semantic_0_loss: 0.0285 - semantic_1_loss: 0.0508 - lr: 5.0489e-05
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0631 - semantic_0_loss: 0.0231 - semantic_1_loss: 0.0400
# Epoch 00070: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0631 - semantic_0_loss: 0.0231 - semantic_1_loss: 0.0400 - lr: 4.9984e-05
# Epoch 71/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0774 - semantic_0_loss: 0.0271 - semantic_1_loss: 0.0502
# Epoch 00071: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0774 - semantic_0_loss: 0.0271 - semantic_1_loss: 0.0502 - lr: 4.9484e-05
# Epoch 72/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0806 - semantic_0_loss: 0.0291 - semantic_1_loss: 0.0516
# Epoch 00072: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0806 - semantic_0_loss: 0.0291 - semantic_1_loss: 0.0516 - lr: 4.8989e-05
# Epoch 73/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0732 - semantic_0_loss: 0.0268 - semantic_1_loss: 0.0465
# Epoch 00073: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0732 - semantic_0_loss: 0.0268 - semantic_1_loss: 0.0465 - lr: 4.8499e-05
# Epoch 74/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0765 - semantic_0_loss: 0.0271 - semantic_1_loss: 0.0494
# Epoch 00074: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0765 - semantic_0_loss: 0.0271 - semantic_1_loss: 0.0494 - lr: 4.8014e-05
# Epoch 75/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0760 - semantic_0_loss: 0.0267 - semantic_1_loss: 0.0493
# Epoch 00075: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0760 - semantic_0_loss: 0.0267 - semantic_1_loss: 0.0493 - lr: 4.7534e-05
# Epoch 76/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0758 - semantic_0_loss: 0.0265 - semantic_1_loss: 0.0493
# Epoch 00076: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0758 - semantic_0_loss: 0.0265 - semantic_1_loss: 0.0493 - lr: 4.7059e-05
# Epoch 77/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0587 - semantic_0_loss: 0.0213 - semantic_1_loss: 0.0375
# Epoch 00077: loss did not improve from 0.05101
# 5/5 [==============================] - 13s 2s/step - loss: 0.0587 - semantic_0_loss: 0.0213 - semantic_1_loss: 0.0375 - lr: 4.6588e-05
# Epoch 78/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0706 - semantic_0_loss: 0.0255 - semantic_1_loss: 0.0452
# Epoch 00078: loss did not improve from 0.05101
# 5/5 [==============================] - 11s 2s/step - loss: 0.0706 - semantic_0_loss: 0.0255 - semantic_1_loss: 0.0452 - lr: 4.6122e-05
# Epoch 79/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0508 - semantic_0_loss: 0.0180 - semantic_1_loss: 0.0328
# Epoch 00079: loss improved from 0.05101 to 0.05078, saving model to models/nuclear20221010.h5
# 5/5 [==============================] - 11s 2s/step - loss: 0.0508 - semantic_0_loss: 0.0180 - semantic_1_loss: 0.0328 - lr: 4.5661e-05
# Epoch 80/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0827 - semantic_0_loss: 0.0283 - semantic_1_loss: 0.0544
# Epoch 00080: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0827 - semantic_0_loss: 0.0283 - semantic_1_loss: 0.0544 - lr: 4.5204e-05
# Epoch 81/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0837 - semantic_0_loss: 0.0306 - semantic_1_loss: 0.0531
# Epoch 00081: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0837 - semantic_0_loss: 0.0306 - semantic_1_loss: 0.0531 - lr: 4.4752e-05
# Epoch 82/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0568 - semantic_0_loss: 0.0207 - semantic_1_loss: 0.0361
# Epoch 00082: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0568 - semantic_0_loss: 0.0207 - semantic_1_loss: 0.0361 - lr: 4.4305e-05
# Epoch 83/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0769 - semantic_0_loss: 0.0289 - semantic_1_loss: 0.0479
# Epoch 00083: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0769 - semantic_0_loss: 0.0289 - semantic_1_loss: 0.0479 - lr: 4.3862e-05
# Epoch 84/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0754 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0500
# Epoch 00084: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0754 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0500 - lr: 4.3423e-05
# Epoch 85/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0706 - semantic_0_loss: 0.0252 - semantic_1_loss: 0.0454
# Epoch 00085: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0706 - semantic_0_loss: 0.0252 - semantic_1_loss: 0.0454 - lr: 4.2989e-05
# Epoch 86/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0551 - semantic_0_loss: 0.0199 - semantic_1_loss: 0.0352
# Epoch 00086: loss did not improve from 0.05078
# 5/5 [==============================] - 10s 2s/step - loss: 0.0551 - semantic_0_loss: 0.0199 - semantic_1_loss: 0.0352 - lr: 4.2559e-05
# Epoch 87/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0773 - semantic_0_loss: 0.0286 - semantic_1_loss: 0.0487
# Epoch 00087: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0773 - semantic_0_loss: 0.0286 - semantic_1_loss: 0.0487 - lr: 4.2133e-05
# Epoch 88/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0617 - semantic_0_loss: 0.0219 - semantic_1_loss: 0.0399
# Epoch 00088: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0617 - semantic_0_loss: 0.0219 - semantic_1_loss: 0.0399 - lr: 4.1712e-05
# Epoch 89/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0686 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0432
# Epoch 00089: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0686 - semantic_0_loss: 0.0254 - semantic_1_loss: 0.0432 - lr: 4.1295e-05
# Epoch 90/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0596 - semantic_0_loss: 0.0221 - semantic_1_loss: 0.0375
# Epoch 00090: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0596 - semantic_0_loss: 0.0221 - semantic_1_loss: 0.0375 - lr: 4.0882e-05
# Epoch 91/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0709 - semantic_0_loss: 0.0249 - semantic_1_loss: 0.0460
# Epoch 00091: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0709 - semantic_0_loss: 0.0249 - semantic_1_loss: 0.0460 - lr: 4.0473e-05
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0611 - semantic_0_loss: 0.0219 - semantic_1_loss: 0.0392
# Epoch 00092: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0611 - semantic_0_loss: 0.0219 - semantic_1_loss: 0.0392 - lr: 4.0068e-05
# Epoch 93/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0737 - semantic_0_loss: 0.0262 - semantic_1_loss: 0.0475
# Epoch 00093: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0737 - semantic_0_loss: 0.0262 - semantic_1_loss: 0.0475 - lr: 3.9668e-05
# Epoch 94/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0687 - semantic_0_loss: 0.0247 - semantic_1_loss: 0.0440
# Epoch 00094: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0687 - semantic_0_loss: 0.0247 - semantic_1_loss: 0.0440 - lr: 3.9271e-05
# Epoch 95/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0577 - semantic_0_loss: 0.0198 - semantic_1_loss: 0.0379
# Epoch 00095: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0577 - semantic_0_loss: 0.0198 - semantic_1_loss: 0.0379 - lr: 3.8878e-05
# Epoch 96/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0615 - semantic_0_loss: 0.0220 - semantic_1_loss: 0.0394
# Epoch 00096: loss did not improve from 0.05078
# 5/5 [==============================] - 14s 2s/step - loss: 0.0615 - semantic_0_loss: 0.0220 - semantic_1_loss: 0.0394 - lr: 3.8490e-05
# Epoch 97/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0612 - semantic_0_loss: 0.0210 - semantic_1_loss: 0.0402
# Epoch 00097: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0612 - semantic_0_loss: 0.0210 - semantic_1_loss: 0.0402 - lr: 3.8105e-05
# Epoch 98/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0598 - semantic_0_loss: 0.0208 - semantic_1_loss: 0.0391
# Epoch 00098: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0598 - semantic_0_loss: 0.0208 - semantic_1_loss: 0.0391 - lr: 3.7724e-05
# Epoch 99/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0584 - semantic_0_loss: 0.0207 - semantic_1_loss: 0.0377
# Epoch 00099: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0584 - semantic_0_loss: 0.0207 - semantic_1_loss: 0.0377 - lr: 3.7346e-05
# Epoch 100/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0527 - semantic_0_loss: 0.0194 - semantic_1_loss: 0.0333
# Epoch 00100: loss did not improve from 0.05078
# 5/5 [==============================] - 11s 2s/step - loss: 0.0527 - semantic_0_loss: 0.0194 - semantic_1_loss: 0.0333 - lr: 3.6973e-05
# Training time:  1121.9670395669527 seconds.

# %%
img=io.imread("images/square_patches/M872956_JML_Position8_CD3_img_patch256x256.png")
print(img.shape)
im=img[:,:,2]
io.imshow(im)
plt.show()
im=np.expand_dims(im, -1) 
im=np.expand_dims(im, 0) 

mask_true=io.imread("images/square_patches/M872956_JML_Position8_CD3_masks_patch256x256.png")
print(mask_true.shape)
io.imshow(mask_true)
plt.show()

# adjust with image_mpp, not working yet

from deepcell_toolbox.utils import resize

image_mpp=1
shape = im.shape
scale_factor = image_mpp / 0.65
new_shape = (int(shape[1] * scale_factor),
             int(shape[2] * scale_factor))
im2 = resize(im, new_shape, data_format='channels_last')
print(im.shape)
im2.shape # shape changes
# Out:
# (256, 256, 3)
# (256, 256)
# /app/software/scikit-image/0.19.1-foss-2021b/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# (1, 256, 256, 1)
# (1, 393, 393, 1)

# %%
# an alternative to application prediction function
from deepcell_toolbox.deep_watershed import deep_watershed
from deepcell.model_zoo.panopticnet import PanopticNet

# predict 
prediction_model = PanopticNet(
    backbone='resnet50',
    input_shape=(256, 256, 1),
    norm_method=None,
    num_semantic_heads=2,
    #num_semantic_classes=[1, 3], # inner distance, pixelwise; makes error
    num_semantic_classes=[1, 1], # seems to inner distance and outdistance (not pixelwise)
    location=True,  # should always be true
    include_top=True)
prediction_model.load_weights("models/nuclear20221010.h5", by_name=True) # load updated weights

# %%
test_images = prediction_model.predict(im)
masks = deep_watershed( # taken from the cytoplasm_segmentation.py
    test_images,
    radius=10, # same as min_distance
    maxima_threshold=0.1, # same as detection_threshold
    interior_threshold=0.01, # same as distance_threshold
    exclude_border=False,
    small_objects_threshold=0)
np.unique(masks[0])
masks[0].shape
io.imshow(masks[0,:,:,0])
#plt.show()
print(syotil.csi(mask_true, masks[0,:,:,0])) #
# Out:
# /app/software/DeepCell/0.11.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0.Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 0.01775147928994083

# %%
# predict using NuclearSegmentation constructed with pretrained model
# same as app = NuclearSegmentation() because the model is the default one
app = NuclearSegmentation(pretrained_model) 
x=im
y, tile_info = app._tile_input(x)
#print(x.shape)
#print(y.shape)
#print(tile_info)
pred = app.predict(y)#, image_mpp=1) 
prd = app._untile_output(pred, tile_info)
io.imshow(prd[0,:,:,0])
#plt.show()
print(syotil.csi(mask_true, prd[0,:,:,0]))
# Out:
# 0.21893491124260356

# %%
# predict using newly trained model
app = NuclearSegmentation(new_model)
x=im
y, tile_info = app._tile_input(x)
#print(x.shape)
#print(y.shape)
#print(tile_info)
pred = app.predict(y, image_mpp=1) 
prd = app._untile_output(pred, tile_info)
io.imshow(prd[0,:,:,0])
#plt.show()
print(syotil.csi(mask_true, prd[0,:,:,0])) #0
# Out:
# 0.0

# %%
# read test files
im0 = io.imread('images/test/M872956_JML_Position8_CD3_test_img.png')
print(im0.shape)
im=im0
io.imshow(im)
plt.show()
im = np.expand_dims(im, axis=-1)
im = np.expand_dims(im, axis=0)

mask_true=io.imread("images/test/M872956_JML_Position8_CD3_test_masks.png")
print(mask_true.shape)
io.imshow(mask_true)
plt.show()

# %%
# predict using newly trained model
app = NuclearSegmentation(new_model)
x=im
y, tile_info = app._tile_input(x)
#print(x.shape)
#print(y.shape)
#print(tile_info)
pred = app.predict(y, image_mpp=1) 
prd = app._untile_output(pred, tile_info)
io.imshow(prd[0,:,:,0])
#plt.show()
print(syotil.csi(mask_true, prd[0,:,:,0])) # 0.21 without passing image_mpp. Setting image_mpp to 1 improves to 0.37

# %%
# predict using NuclearSegmentation constructed with pretrained model
# same as app = NuclearSegmentation() because the model is the default one
app = NuclearSegmentation(pretrained_model) 
x=im
y, tile_info = app._tile_input(x)
#print(x.shape)
#print(y.shape)
#print(tile_info)
pred = app.predict(y, image_mpp=1) 
prd = app._untile_output(pred, tile_info)
io.imshow(prd[0,:,:,0])
#plt.show()
print(syotil.csi(mask_true, prd[0,:,:,0])) # 0.21 without passing image_mpp. Setting image_mpp to 1 improves to 0.37
