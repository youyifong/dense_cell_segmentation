# %% [markdown]
# This notebook is based on Intro to DeepCell notebook. It works on tensorflow 2.7.1.<br>
# It trains a model with three heads: inner distance, outer distance, and fgbg.
# Trained model does not perform well on a CD3 test image.

# %%
import syotil

import numpy as np
from skimage import io
from matplotlib import pyplot as plt
# %matplotlib inline
from timeit import default_timer

import tensorflow as tf
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.losses import MSE

import deepcell
from deepcell.utils.train_utils import rate_scheduler, get_callbacks, count_gpus
from deepcell.losses import weighted_categorical_crossentropy
from deepcell.model_zoo.panopticnet import PanopticNet
from deepcell_toolbox.deep_watershed import deep_watershed
from deepcell import image_generators

print(tf.__version__)
# Out:
# 2.7.1

# %%
base_url = ('https://deepcell-data.s3-us-west-1.amazonaws.com/'
            'demos/janelia/hela_s3_{}_256.npz')

nuclear = deepcell.datasets.Dataset(
    path='nuclear.npz',
    url=base_url.format('nuclear'),
     file_hash=None,
    metadata=None
)

fluo_cyto = deepcell.datasets.Dataset(
    path='fluo_cyto.npz',
    url=base_url.format('fluo_cyto'),
     file_hash=None,
    metadata=None
)

phase = deepcell.datasets.Dataset(
    path='phase.npz',
    url=base_url.format('phase'),
     file_hash=None,
    metadata=None
)

# %%
dataset = phase  # nuclear, phase, fluo_cyto
model_name = 'phase_deep_watershed'

min_objects = 2

test_size = 0.2 # fraction of data saved as test
seed = 0 # seed for random train-test split

(X_train, y_train), (X_test, y_test) = dataset.load_data(
    test_size=test_size, seed=seed)

print('X_train.shape: {}\nX_test.shape: {}'.format(
    X_train.shape, X_test.shape))
transforms = ['inner-distance', 'outer-distance', 'fgbg']
transforms_kwargs = {'outer-distance': {'erosion_width': 0}}


# use augmentation for training but not validation
datagen = image_generators.SemanticDataGenerator(
    rotation_range=180,
    fill_mode='reflect',
    zoom_range=(0.75, 1.25),
    horizontal_flip=True,
    vertical_flip=True)

datagen_val = image_generators.SemanticDataGenerator()

batch_size = 8

train_data = datagen.flow(
    {'X': X_train, 'y': y_train},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    {'X': X_test, 'y': y_test},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)
# Out:
# X_train.shape: (1872, 256, 256, 1)
# X_test.shape: (468, 256, 256, 1)

# %%
print(y_train.shape)

i=5

io.imshow(X_train[i,:,:,0])
plt.show()
#print(X_train[i,:,:,0])

tmp = syotil.masks_to_outlines(y_train[i,:,:,0])
io.imshow(tmp)
plt.show()
# Out:
# (1872, 256, 256, 1)
# /app/software/scikit-image/0.19.1-foss-2021b/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
semantic_classes = [1, 1, 2] # inner distance, outer distance, fgbg

model = PanopticNet(
    backbone='resnet50',
    input_shape=X_train.shape[1:],
    norm_method='whole_image',
    num_semantic_classes=semantic_classes)

lr = 1e-4
optimizer = Adam(lr=lr, clipnorm=0.001)
lr_sched = rate_scheduler(lr=lr, decay=0.99)

# Create a dictionary of losses for each semantic head

def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss

loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)
        
model.compile(loss=loss, optimizer=optimizer)

[(layer.name, layer.output_shape) for layer in filter(lambda x: x.name.startswith('semantic_'), model.layers)]
# Out:
# 2022-10-29 10:47:29.148316: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-10-29 10:47:30.737200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10429 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:5e:00.0, compute capability: 6.1
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [('semantic_0', (None, 256, 256, 1)),
#  ('semantic_1', (None, 256, 256, 1)),
#  ('semantic_2', (None, 256, 256, 2))]

# %%
# fit the model

model_path = '{}.h5'.format(model_name)

print('Training on', count_gpus(), 'GPUs.')

train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    monitor='val_loss',
    verbose=1)

loss_history = model.fit(
    train_data,
    steps_per_epoch=train_data.y.shape[0] // batch_size,
    epochs=50,
    validation_data=val_data,
    validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
# Out:
# 2022-10-29 10:47:35.497245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 10429 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:5e:00.0, compute capability: 6.1
# Training on 1 GPUs.
# Epoch 1/50
# 2022-10-29 10:47:52.218791: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8202
# 234/234 [==============================] - ETA: 0s - loss: 0.1250 - semantic_0_loss: 0.0840 - semantic_1_loss: 0.0389 - semantic_2_loss: 0.0021
# Epoch 00001: val_loss improved from inf to 0.14667, saving model to phase_deep_watershed.h5
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 234/234 [==============================] - 90s 283ms/step - loss: 0.1250 - semantic_0_loss: 0.0840 - semantic_1_loss: 0.0389 - semantic_2_loss: 0.0021 - val_loss: 0.1467 - val_semantic_0_loss: 0.0045 - val_semantic_1_loss: 0.0616 - val_semantic_2_loss: 0.0806 - lr: 1.0000e-04
# Epoch 2/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0107 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0072 - semantic_2_loss: 0.0010
# Epoch 00002: val_loss improved from 0.14667 to 0.07035, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 275ms/step - loss: 0.0107 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0072 - semantic_2_loss: 0.0010 - val_loss: 0.0703 - val_semantic_0_loss: 0.0043 - val_semantic_1_loss: 0.0542 - val_semantic_2_loss: 0.0119 - lr: 9.9000e-05
# Epoch 3/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0092 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0061 - semantic_2_loss: 8.9585e-04
# Epoch 00003: val_loss improved from 0.07035 to 0.01616, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 66s 282ms/step - loss: 0.0092 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0061 - semantic_2_loss: 8.9585e-04 - val_loss: 0.0162 - val_semantic_0_loss: 0.0026 - val_semantic_1_loss: 0.0113 - val_semantic_2_loss: 0.0022 - lr: 9.8010e-05
# Epoch 4/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0085 - semantic_0_loss: 0.0021 - semantic_1_loss: 0.0055 - semantic_2_loss: 8.4532e-04
# Epoch 00004: val_loss improved from 0.01616 to 0.00792, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 66s 283ms/step - loss: 0.0085 - semantic_0_loss: 0.0021 - semantic_1_loss: 0.0055 - semantic_2_loss: 8.4532e-04 - val_loss: 0.0079 - val_semantic_0_loss: 0.0021 - val_semantic_1_loss: 0.0050 - val_semantic_2_loss: 8.0689e-04 - lr: 9.7030e-05
# Epoch 5/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0020 - semantic_1_loss: 0.0049 - semantic_2_loss: 7.9429e-04
# Epoch 00005: val_loss improved from 0.00792 to 0.00710, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 66s 279ms/step - loss: 0.0077 - semantic_0_loss: 0.0020 - semantic_1_loss: 0.0049 - semantic_2_loss: 7.9429e-04 - val_loss: 0.0071 - val_semantic_0_loss: 0.0021 - val_semantic_1_loss: 0.0043 - val_semantic_2_loss: 7.3888e-04 - lr: 9.6060e-05
# Epoch 6/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0071 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0044 - semantic_2_loss: 7.5769e-04
# Epoch 00006: val_loss did not improve from 0.00710
# 234/234 [==============================] - 63s 269ms/step - loss: 0.0071 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0044 - semantic_2_loss: 7.5769e-04 - val_loss: 0.0073 - val_semantic_0_loss: 0.0020 - val_semantic_1_loss: 0.0045 - val_semantic_2_loss: 8.0018e-04 - lr: 9.5099e-05
# Epoch 7/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0068 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0043 - semantic_2_loss: 7.3942e-04
# Epoch 00007: val_loss improved from 0.00710 to 0.00679, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 278ms/step - loss: 0.0068 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0043 - semantic_2_loss: 7.3942e-04 - val_loss: 0.0068 - val_semantic_0_loss: 0.0019 - val_semantic_1_loss: 0.0041 - val_semantic_2_loss: 7.4892e-04 - lr: 9.4148e-05
# Epoch 8/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0065 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0040 - semantic_2_loss: 7.2271e-04
# Epoch 00008: val_loss improved from 0.00679 to 0.00653, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 63s 270ms/step - loss: 0.0065 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0040 - semantic_2_loss: 7.2271e-04 - val_loss: 0.0065 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0040 - val_semantic_2_loss: 7.0122e-04 - lr: 9.3207e-05
# Epoch 9/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0062 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0039 - semantic_2_loss: 7.0903e-04
# Epoch 00009: val_loss did not improve from 0.00653
# 234/234 [==============================] - 63s 268ms/step - loss: 0.0062 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0039 - semantic_2_loss: 7.0903e-04 - val_loss: 0.0066 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0041 - val_semantic_2_loss: 7.0559e-04 - lr: 9.2274e-05
# Epoch 10/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0062 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0038 - semantic_2_loss: 7.0563e-04
# Epoch 00010: val_loss did not improve from 0.00653
# 234/234 [==============================] - 61s 260ms/step - loss: 0.0062 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0038 - semantic_2_loss: 7.0563e-04 - val_loss: 0.0066 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0040 - val_semantic_2_loss: 7.2397e-04 - lr: 9.1352e-05
# Epoch 11/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0060 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0037 - semantic_2_loss: 6.9360e-04
# Epoch 00011: val_loss improved from 0.00653 to 0.00632, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 278ms/step - loss: 0.0060 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0037 - semantic_2_loss: 6.9360e-04 - val_loss: 0.0063 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0038 - val_semantic_2_loss: 6.9380e-04 - lr: 9.0438e-05
# Epoch 12/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0059 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0036 - semantic_2_loss: 6.8488e-04
# Epoch 00012: val_loss improved from 0.00632 to 0.00624, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 278ms/step - loss: 0.0059 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0036 - semantic_2_loss: 6.8488e-04 - val_loss: 0.0062 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0038 - val_semantic_2_loss: 7.3047e-04 - lr: 8.9534e-05
# Epoch 13/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0057 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0035 - semantic_2_loss: 6.8164e-04
# Epoch 00013: val_loss did not improve from 0.00624
# 234/234 [==============================] - 64s 272ms/step - loss: 0.0057 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0035 - semantic_2_loss: 6.8164e-04 - val_loss: 0.0066 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0040 - val_semantic_2_loss: 7.7488e-04 - lr: 8.8638e-05
# Epoch 14/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0056 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0034 - semantic_2_loss: 6.6807e-04
# Epoch 00014: val_loss improved from 0.00624 to 0.00599, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 66s 280ms/step - loss: 0.0056 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0034 - semantic_2_loss: 6.6807e-04 - val_loss: 0.0060 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0036 - val_semantic_2_loss: 6.6723e-04 - lr: 8.7752e-05
# Epoch 15/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0055 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0033 - semantic_2_loss: 6.6883e-04
# Epoch 00015: val_loss improved from 0.00599 to 0.00598, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 276ms/step - loss: 0.0055 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0033 - semantic_2_loss: 6.6883e-04 - val_loss: 0.0060 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0036 - val_semantic_2_loss: 6.6567e-04 - lr: 8.6875e-05
# Epoch 16/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0054 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0032 - semantic_2_loss: 6.5436e-04
# Epoch 00016: val_loss did not improve from 0.00598
# 234/234 [==============================] - 64s 271ms/step - loss: 0.0054 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0032 - semantic_2_loss: 6.5436e-04 - val_loss: 0.0062 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0036 - val_semantic_2_loss: 7.6279e-04 - lr: 8.6006e-05
# Epoch 17/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0053 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0032 - semantic_2_loss: 6.5228e-04
# Epoch 00017: val_loss improved from 0.00598 to 0.00593, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 276ms/step - loss: 0.0053 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0032 - semantic_2_loss: 6.5228e-04 - val_loss: 0.0059 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0035 - val_semantic_2_loss: 7.6178e-04 - lr: 8.5146e-05
# Epoch 18/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0053 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0032 - semantic_2_loss: 6.5051e-04
# Epoch 00018: val_loss improved from 0.00593 to 0.00582, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 64s 274ms/step - loss: 0.0053 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0032 - semantic_2_loss: 6.5051e-04 - val_loss: 0.0058 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0034 - val_semantic_2_loss: 7.0646e-04 - lr: 8.4294e-05
# Epoch 19/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0052 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0031 - semantic_2_loss: 6.4259e-04
# Epoch 00019: val_loss improved from 0.00582 to 0.00581, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 276ms/step - loss: 0.0052 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0031 - semantic_2_loss: 6.4259e-04 - val_loss: 0.0058 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0034 - val_semantic_2_loss: 7.1070e-04 - lr: 8.3451e-05
# Epoch 20/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0051 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0031 - semantic_2_loss: 6.3627e-04
# Epoch 00020: val_loss improved from 0.00581 to 0.00565, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 66s 280ms/step - loss: 0.0051 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0031 - semantic_2_loss: 6.3627e-04 - val_loss: 0.0057 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0033 - val_semantic_2_loss: 6.3871e-04 - lr: 8.2617e-05
# Epoch 21/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0050 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0030 - semantic_2_loss: 6.3299e-04
# Epoch 00021: val_loss did not improve from 0.00565
# 234/234 [==============================] - 63s 269ms/step - loss: 0.0050 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0030 - semantic_2_loss: 6.3299e-04 - val_loss: 0.0058 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0034 - val_semantic_2_loss: 6.9063e-04 - lr: 8.1791e-05
# Epoch 22/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0050 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0030 - semantic_2_loss: 6.3028e-04
# Epoch 00022: val_loss did not improve from 0.00565
# 234/234 [==============================] - 62s 266ms/step - loss: 0.0050 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0030 - semantic_2_loss: 6.3028e-04 - val_loss: 0.0061 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0036 - val_semantic_2_loss: 7.8808e-04 - lr: 8.0973e-05
# Epoch 23/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0049 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0029 - semantic_2_loss: 6.2167e-04
# Epoch 00023: val_loss improved from 0.00565 to 0.00526, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 276ms/step - loss: 0.0049 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0029 - semantic_2_loss: 6.2167e-04 - val_loss: 0.0053 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0030 - val_semantic_2_loss: 6.0969e-04 - lr: 8.0163e-05
# Epoch 24/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0048 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0029 - semantic_2_loss: 6.1940e-04
# Epoch 00024: val_loss did not improve from 0.00526
# 234/234 [==============================] - 65s 275ms/step - loss: 0.0048 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0029 - semantic_2_loss: 6.1940e-04 - val_loss: 0.0059 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0035 - val_semantic_2_loss: 7.1037e-04 - lr: 7.9361e-05
# Epoch 25/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0047 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0028 - semantic_2_loss: 6.1599e-04
# Epoch 00025: val_loss did not improve from 0.00526
# 234/234 [==============================] - 62s 262ms/step - loss: 0.0047 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0028 - semantic_2_loss: 6.1599e-04 - val_loss: 0.0058 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0034 - val_semantic_2_loss: 6.9674e-04 - lr: 7.8568e-05
# Epoch 26/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0046 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0028 - semantic_2_loss: 6.1320e-04
# Epoch 00026: val_loss did not improve from 0.00526
# 234/234 [==============================] - 63s 267ms/step - loss: 0.0046 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0028 - semantic_2_loss: 6.1320e-04 - val_loss: 0.0058 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0034 - val_semantic_2_loss: 6.9070e-04 - lr: 7.7782e-05
# Epoch 27/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0046 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0027 - semantic_2_loss: 6.1168e-04
# Epoch 00027: val_loss did not improve from 0.00526
# 234/234 [==============================] - 61s 261ms/step - loss: 0.0046 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0027 - semantic_2_loss: 6.1168e-04 - val_loss: 0.0055 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0032 - val_semantic_2_loss: 7.1466e-04 - lr: 7.7004e-05
# Epoch 28/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0046 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0027 - semantic_2_loss: 6.0421e-04
# Epoch 00028: val_loss did not improve from 0.00526
# 234/234 [==============================] - 63s 267ms/step - loss: 0.0046 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0027 - semantic_2_loss: 6.0421e-04 - val_loss: 0.0058 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0034 - val_semantic_2_loss: 7.0403e-04 - lr: 7.6234e-05
# Epoch 29/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0045 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 6.0032e-04
# Epoch 00029: val_loss did not improve from 0.00526
# 234/234 [==============================] - 63s 270ms/step - loss: 0.0045 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 6.0032e-04 - val_loss: 0.0055 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0032 - val_semantic_2_loss: 6.9069e-04 - lr: 7.5472e-05
# Epoch 30/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0045 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 5.9620e-04
# Epoch 00030: val_loss improved from 0.00526 to 0.00516, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 275ms/step - loss: 0.0045 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 5.9620e-04 - val_loss: 0.0052 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 6.2438e-04 - lr: 7.4717e-05
# Epoch 31/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0044 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 5.9711e-04
# Epoch 00031: val_loss did not improve from 0.00516
# 234/234 [==============================] - 63s 270ms/step - loss: 0.0044 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 5.9711e-04 - val_loss: 0.0052 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0030 - val_semantic_2_loss: 6.1399e-04 - lr: 7.3970e-05
# Epoch 32/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0044 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 5.9154e-04
# Epoch 00032: val_loss did not improve from 0.00516
# 234/234 [==============================] - 63s 267ms/step - loss: 0.0044 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0026 - semantic_2_loss: 5.9154e-04 - val_loss: 0.0054 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0032 - val_semantic_2_loss: 6.7196e-04 - lr: 7.3230e-05
# Epoch 33/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0043 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0025 - semantic_2_loss: 5.8615e-04
# Epoch 00033: val_loss did not improve from 0.00516
# 234/234 [==============================] - 62s 266ms/step - loss: 0.0043 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0025 - semantic_2_loss: 5.8615e-04 - val_loss: 0.0053 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0030 - val_semantic_2_loss: 6.3428e-04 - lr: 7.2498e-05
# Epoch 34/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0043 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0025 - semantic_2_loss: 5.8657e-04
# Epoch 00034: val_loss did not improve from 0.00516
# 234/234 [==============================] - 62s 266ms/step - loss: 0.0043 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0025 - semantic_2_loss: 5.8657e-04 - val_loss: 0.0055 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0032 - val_semantic_2_loss: 7.2122e-04 - lr: 7.1773e-05
# Epoch 35/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0042 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0025 - semantic_2_loss: 5.7969e-04
# Epoch 00035: val_loss did not improve from 0.00516
# 234/234 [==============================] - 62s 265ms/step - loss: 0.0042 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0025 - semantic_2_loss: 5.7969e-04 - val_loss: 0.0054 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0031 - val_semantic_2_loss: 7.0122e-04 - lr: 7.1055e-05
# Epoch 36/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7945e-04
# Epoch 00036: val_loss did not improve from 0.00516
# 234/234 [==============================] - 62s 264ms/step - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7945e-04 - val_loss: 0.0052 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0030 - val_semantic_2_loss: 6.5388e-04 - lr: 7.0345e-05
# Epoch 37/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7731e-04
# Epoch 00037: val_loss improved from 0.00516 to 0.00512, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 276ms/step - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7731e-04 - val_loss: 0.0051 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 6.6706e-04 - lr: 6.9641e-05
# Epoch 38/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7389e-04
# Epoch 00038: val_loss improved from 0.00512 to 0.00501, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 64s 271ms/step - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7389e-04 - val_loss: 0.0050 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 6.0567e-04 - lr: 6.8945e-05
# Epoch 39/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7268e-04
# Epoch 00039: val_loss improved from 0.00501 to 0.00495, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 276ms/step - loss: 0.0041 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.7268e-04 - val_loss: 0.0050 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 6.0645e-04 - lr: 6.8255e-05
# Epoch 40/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0040 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.6934e-04
# Epoch 00040: val_loss did not improve from 0.00495
# 234/234 [==============================] - 63s 268ms/step - loss: 0.0040 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0024 - semantic_2_loss: 5.6934e-04 - val_loss: 0.0050 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 6.4828e-04 - lr: 6.7573e-05
# Epoch 41/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0040 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6964e-04
# Epoch 00041: val_loss improved from 0.00495 to 0.00486, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 277ms/step - loss: 0.0040 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6964e-04 - val_loss: 0.0049 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 6.1801e-04 - lr: 6.6897e-05
# Epoch 42/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0040 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6732e-04
# Epoch 00042: val_loss did not improve from 0.00486
# 234/234 [==============================] - 62s 264ms/step - loss: 0.0040 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6732e-04 - val_loss: 0.0050 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 6.1902e-04 - lr: 6.6228e-05
# Epoch 43/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0039 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6447e-04
# Epoch 00043: val_loss did not improve from 0.00486
# 234/234 [==============================] - 62s 265ms/step - loss: 0.0039 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6447e-04 - val_loss: 0.0049 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 6.2685e-04 - lr: 6.5566e-05
# Epoch 44/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0039 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6310e-04
# Epoch 00044: val_loss did not improve from 0.00486
# 234/234 [==============================] - 63s 268ms/step - loss: 0.0039 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6310e-04 - val_loss: 0.0050 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 6.4506e-04 - lr: 6.4910e-05
# Epoch 45/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0039 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6206e-04
# Epoch 00045: val_loss did not improve from 0.00486
# 234/234 [==============================] - 62s 265ms/step - loss: 0.0039 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0023 - semantic_2_loss: 5.6206e-04 - val_loss: 0.0051 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 6.7539e-04 - lr: 6.4261e-05
# Epoch 46/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0038 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5876e-04
# Epoch 00046: val_loss did not improve from 0.00486
# 234/234 [==============================] - 62s 263ms/step - loss: 0.0038 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5876e-04 - val_loss: 0.0049 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 6.0474e-04 - lr: 6.3619e-05
# Epoch 47/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0038 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5479e-04
# Epoch 00047: val_loss did not improve from 0.00486
# 234/234 [==============================] - 62s 264ms/step - loss: 0.0038 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5479e-04 - val_loss: 0.0052 - val_semantic_0_loss: 0.0016 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 6.5797e-04 - lr: 6.2982e-05
# Epoch 48/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0038 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5406e-04
# Epoch 00048: val_loss improved from 0.00486 to 0.00481, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 66s 280ms/step - loss: 0.0038 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5406e-04 - val_loss: 0.0048 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 6.1343e-04 - lr: 6.2353e-05
# Epoch 49/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0037 - semantic_0_loss: 9.8338e-04 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5202e-04
# Epoch 00049: val_loss improved from 0.00481 to 0.00474, saving model to phase_deep_watershed.h5
# 234/234 [==============================] - 65s 278ms/step - loss: 0.0037 - semantic_0_loss: 9.8338e-04 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5202e-04 - val_loss: 0.0047 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 5.7981e-04 - lr: 6.1729e-05
# Epoch 50/50
# 234/234 [==============================] - ETA: 0s - loss: 0.0037 - semantic_0_loss: 9.9786e-04 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5311e-04
# Epoch 00050: val_loss did not improve from 0.00474
# 234/234 [==============================] - 64s 271ms/step - loss: 0.0037 - semantic_0_loss: 9.9786e-04 - semantic_1_loss: 0.0022 - semantic_2_loss: 5.5311e-04 - val_loss: 0.0048 - val_semantic_0_loss: 0.0015 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 5.8451e-04 - lr: 6.1112e-05

# %%
# create prediction model


prediction_model = PanopticNet(
    backbone='resnet50',
    norm_method='whole_image',
    num_semantic_classes=[1, 1], # inner distance, outer distance
    input_shape=X_test.shape[1:]
)

prediction_model.load_weights(model_path, by_name=True)

# %%
# make predictions on testing data

start = default_timer()
test_images = prediction_model.predict(X_test)
watershed_time = default_timer() - start

print('Watershed segmentation of shape', test_images[0].shape,
      'in', watershed_time, 'seconds.')


masks = deep_watershed(
    test_images,
    min_distance=10,
    detection_threshold=0.1,
    distance_threshold=0.01,
    exclude_border=False,
    small_objects_threshold=0)
# Out:
# Watershed segmentation of shape (468, 256, 256, 1) in 5.661037954501808 seconds.
# /app/software/DeepCell/0.11.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0.Please use `footprint` instead.
#   markers = h_maxima(image=maxima,

# %%
X_test.shape
# Out:
# (468, 256, 256, 1)

# %%
io.imshow(X_test[1,:,:,0])
plt.show()
io.imshow(y_test[1,:,:,0])
plt.show()
syotil.csi(y_test[1,:,:,0], masks[1,:,:,0])
# Out:
# 1.0

# %%
# read CD3 data

img=io.imread("images/square_patches/M872956_JML_Position8_CD3_img_patch256x256.png")
print(img.shape)
X_cd3=img[:,:,2]
#io.imshow(im)
#plt.show()
X_cd3=np.expand_dims(X_cd3, -1) 
X_cd3=np.expand_dims(X_cd3, 0) 

y_cd3=io.imread("images/square_patches/M872956_JML_Position8_CD3_masks_patch256x256.png")
print(y_cd3.shape)
#io.imshow(mask_true)
#plt.show()
y_cd3=np.expand_dims(y_cd3, -1) 
y_cd3=np.expand_dims(y_cd3, 0) 

batch_size_cd3 = 1

print(X_cd3.shape)
print(y_cd3.shape)

train_cd3 = datagen.flow(
    {'X': X_cd3, 'y': y_cd3},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

val_cd3 = datagen_val.flow(
    {'X': X_cd3, 'y': y_cd3},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)
# Out:
# (256, 256, 3)
# (256, 256)
# (1, 256, 256, 1)
# (1, 256, 256, 1)

# %%
# make predictions on CD3 data
start = default_timer()
test_images = prediction_model.predict(X_cd3)
watershed_time = default_timer() - start

pred_cd3 = deep_watershed(
    test_images,
    min_distance=0,
    detection_threshold=0.001,
    distance_threshold=0.0,
    exclude_border=False,
    small_objects_threshold=0)

# %%
print(y_cd3.shape, pred_cd3.shape)
io.imshow(y_cd3[0,:,:,0])
plt.show()
io.imshow(pred_cd3[0,:,:,0])
plt.show()
syotil.csi(y_cd3[0,:,:,0], pred_cd3[0,:,:,0])
# the cyto_fluo training data cells are bigger than CD3 cells
# Out:
# (1, 256, 256, 1) (1, 256, 256, 1)
# 0.0

# %%
# fit again with K data

loss_history = model.fit(
    train_cd3,
    steps_per_epoch=train_cd3.y.shape[0] // batch_size_cd3,
    epochs=100,
    validation_data=val_cd3,
    validation_steps=val_cd3.y.shape[0] // batch_size_cd3,
    callbacks=train_callbacks)
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1137 - semantic_0_loss: 0.0424 - semantic_1_loss: 0.0560 - semantic_2_loss: 0.0153
# Epoch 00001: val_loss did not improve from 0.00474
# 1/1 [==============================] - 2s 2s/step - loss: 0.1137 - semantic_0_loss: 0.0424 - semantic_1_loss: 0.0560 - semantic_2_loss: 0.0153 - val_loss: 0.1018 - val_semantic_0_loss: 0.0361 - val_semantic_1_loss: 0.0532 - val_semantic_2_loss: 0.0126 - lr: 1.0000e-04
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 0.
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0453 - semantic_0_loss: 0.0186 - semantic_1_loss: 0.0235 - semantic_2_loss: 0.0031
# Epoch 00034: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0453 - semantic_0_loss: 0.0186 - semantic_1_loss: 0.0235 - semantic_2_loss: 0.0031 - val_loss: 0.0595 - val_semantic_0_loss: 0.0243 - val_semantic_1_loss: 0.0308 - val_semantic_2_loss: 0.0044 - lr: 7.1773e-05
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0385 - semantic_0_loss: 0.0159 - semantic_1_loss: 0.0198 - semantic_2_loss: 0.0027
# Epoch 00035: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0385 - semantic_0_loss: 0.0159 - semantic_1_loss: 0.0198 - semantic_2_loss: 0.0027 - val_loss: 0.0588 - val_semantic_0_loss: 0.0241 - val_semantic_1_loss: 0.0304 - val_semantic_2_loss: 0.0043 - lr: 7.1055e-05
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0582 - semantic_0_loss: 0.0239 - semantic_1_loss: 0.0306 - semantic_2_loss: 0.0037
# Epoch 00036: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0582 - semantic_0_loss: 0.0239 - semantic_1_loss: 0.0306 - semantic_2_loss: 0.0037 - val_loss: 0.0581 - val_semantic_0_loss: 0.0239 - val_semantic_1_loss: 0.0299 - val_semantic_2_loss: 0.0042 - lr: 7.0345e-05
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0415 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0213 - semantic_2_loss: 0.0029
# Epoch 00037: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0415 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0213 - semantic_2_loss: 0.0029 - val_loss: 0.0574 - val_semantic_0_loss: 0.0237 - val_semantic_1_loss: 0.0296 - val_semantic_2_loss: 0.0041 - lr: 6.9641e-05
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0556 - semantic_0_loss: 0.0219 - semantic_1_loss: 0.0300 - semantic_2_loss: 0.0037
# Epoch 00038: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0556 - semantic_0_loss: 0.0219 - semantic_1_loss: 0.0300 - semantic_2_loss: 0.0037 - val_loss: 0.0567 - val_semantic_0_loss: 0.0235 - val_semantic_1_loss: 0.0291 - val_semantic_2_loss: 0.0040 - lr: 6.8945e-05
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0561 - semantic_0_loss: 0.0221 - semantic_1_loss: 0.0303 - semantic_2_loss: 0.0036
# Epoch 00039: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0561 - semantic_0_loss: 0.0221 - semantic_1_loss: 0.0303 - semantic_2_loss: 0.0036 - val_loss: 0.0561 - val_semantic_0_loss: 0.0234 - val_semantic_1_loss: 0.0288 - val_semantic_2_loss: 0.0039 - lr: 6.8255e-05
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0421 - semantic_0_loss: 0.0173 - semantic_1_loss: 0.0217 - semantic_2_loss: 0.0031
# Epoch 00040: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0421 - semantic_0_loss: 0.0173 - semantic_1_loss: 0.0217 - semantic_2_loss: 0.0031 - val_loss: 0.0557 - val_semantic_0_loss: 0.0233 - val_semantic_1_loss: 0.0285 - val_semantic_2_loss: 0.0039 - lr: 6.7573e-05
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0509 - semantic_0_loss: 0.0217 - semantic_1_loss: 0.0262 - semantic_2_loss: 0.0031
# Epoch 00041: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0509 - semantic_0_loss: 0.0217 - semantic_1_loss: 0.0262 - semantic_2_loss: 0.0031 - val_loss: 0.0554 - val_semantic_0_loss: 0.0232 - val_semantic_1_loss: 0.0283 - val_semantic_2_loss: 0.0039 - lr: 6.6897e-05
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0567 - semantic_0_loss: 0.0223 - semantic_1_loss: 0.0308 - semantic_2_loss: 0.0036
# Epoch 00042: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0567 - semantic_0_loss: 0.0223 - semantic_1_loss: 0.0308 - semantic_2_loss: 0.0036 - val_loss: 0.0550 - val_semantic_0_loss: 0.0231 - val_semantic_1_loss: 0.0280 - val_semantic_2_loss: 0.0039 - lr: 6.6228e-05
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0379 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0187 - semantic_2_loss: 0.0026
# Epoch 00043: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0379 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0187 - semantic_2_loss: 0.0026 - val_loss: 0.0546 - val_semantic_0_loss: 0.0229 - val_semantic_1_loss: 0.0278 - val_semantic_2_loss: 0.0039 - lr: 6.5566e-05
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0393 - semantic_0_loss: 0.0167 - semantic_1_loss: 0.0199 - semantic_2_loss: 0.0027
# Epoch 00044: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0393 - semantic_0_loss: 0.0167 - semantic_1_loss: 0.0199 - semantic_2_loss: 0.0027 - val_loss: 0.0541 - val_semantic_0_loss: 0.0227 - val_semantic_1_loss: 0.0275 - val_semantic_2_loss: 0.0040 - lr: 6.4910e-05
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0401 - semantic_0_loss: 0.0171 - semantic_1_loss: 0.0203 - semantic_2_loss: 0.0027
# Epoch 00045: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0401 - semantic_0_loss: 0.0171 - semantic_1_loss: 0.0203 - semantic_2_loss: 0.0027 - val_loss: 0.0534 - val_semantic_0_loss: 0.0224 - val_semantic_1_loss: 0.0271 - val_semantic_2_loss: 0.0039 - lr: 6.4261e-05
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0441 - semantic_0_loss: 0.0175 - semantic_1_loss: 0.0238 - semantic_2_loss: 0.0028
# Epoch 00046: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0441 - semantic_0_loss: 0.0175 - semantic_1_loss: 0.0238 - semantic_2_loss: 0.0028 - val_loss: 0.0529 - val_semantic_0_loss: 0.0221 - val_semantic_1_loss: 0.0269 - val_semantic_2_loss: 0.0039 - lr: 6.3619e-05
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0531 - semantic_0_loss: 0.0208 - semantic_1_loss: 0.0288 - semantic_2_loss: 0.0035
# Epoch 00047: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0531 - semantic_0_loss: 0.0208 - semantic_1_loss: 0.0288 - semantic_2_loss: 0.0035 - val_loss: 0.0522 - val_semantic_0_loss: 0.0219 - val_semantic_1_loss: 0.0265 - val_semantic_2_loss: 0.0038 - lr: 6.2982e-05
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0486 - semantic_0_loss: 0.0192 - semantic_1_loss: 0.0261 - semantic_2_loss: 0.0033
# Epoch 00048: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0486 - semantic_0_loss: 0.0192 - semantic_1_loss: 0.0261 - semantic_2_loss: 0.0033 - val_loss: 0.0515 - val_semantic_0_loss: 0.0217 - val_semantic_1_loss: 0.0261 - val_semantic_2_loss: 0.0037 - lr: 6.2353e-05
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0442 - semantic_0_loss: 0.0185 - semantic_1_loss: 0.0226 - semantic_2_loss: 0.0031
# Epoch 00049: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0442 - semantic_0_loss: 0.0185 - semantic_1_loss: 0.0226 - semantic_2_loss: 0.0031 - val_loss: 0.0509 - val_semantic_0_loss: 0.0215 - val_semantic_1_loss: 0.0258 - val_semantic_2_loss: 0.0036 - lr: 6.1729e-05
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0330 - semantic_0_loss: 0.0136 - semantic_1_loss: 0.0168 - semantic_2_loss: 0.0026
# Epoch 00050: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0330 - semantic_0_loss: 0.0136 - semantic_1_loss: 0.0168 - semantic_2_loss: 0.0026 - val_loss: 0.0503 - val_semantic_0_loss: 0.0214 - val_semantic_1_loss: 0.0254 - val_semantic_2_loss: 0.0035 - lr: 6.1112e-05
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0388 - semantic_0_loss: 0.0154 - semantic_1_loss: 0.0205 - semantic_2_loss: 0.0030
# Epoch 00051: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0388 - semantic_0_loss: 0.0154 - semantic_1_loss: 0.0205 - semantic_2_loss: 0.0030 - val_loss: 0.0499 - val_semantic_0_loss: 0.0212 - val_semantic_1_loss: 0.0252 - val_semantic_2_loss: 0.0035 - lr: 6.0501e-05
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0308 - semantic_0_loss: 0.0127 - semantic_1_loss: 0.0157 - semantic_2_loss: 0.0024
# Epoch 00052: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0308 - semantic_0_loss: 0.0127 - semantic_1_loss: 0.0157 - semantic_2_loss: 0.0024 - val_loss: 0.0496 - val_semantic_0_loss: 0.0211 - val_semantic_1_loss: 0.0250 - val_semantic_2_loss: 0.0035 - lr: 5.9896e-05
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0443 - semantic_0_loss: 0.0178 - semantic_1_loss: 0.0235 - semantic_2_loss: 0.0030
# Epoch 00053: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0443 - semantic_0_loss: 0.0178 - semantic_1_loss: 0.0235 - semantic_2_loss: 0.0030 - val_loss: 0.0493 - val_semantic_0_loss: 0.0209 - val_semantic_1_loss: 0.0249 - val_semantic_2_loss: 0.0034 - lr: 5.9297e-05
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0369 - semantic_0_loss: 0.0157 - semantic_1_loss: 0.0186 - semantic_2_loss: 0.0026
# Epoch 00054: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0369 - semantic_0_loss: 0.0157 - semantic_1_loss: 0.0186 - semantic_2_loss: 0.0026 - val_loss: 0.0489 - val_semantic_0_loss: 0.0208 - val_semantic_1_loss: 0.0247 - val_semantic_2_loss: 0.0034 - lr: 5.8704e-05
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0467 - semantic_0_loss: 0.0187 - semantic_1_loss: 0.0249 - semantic_2_loss: 0.0031
# Epoch 00055: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0467 - semantic_0_loss: 0.0187 - semantic_1_loss: 0.0249 - semantic_2_loss: 0.0031 - val_loss: 0.0486 - val_semantic_0_loss: 0.0206 - val_semantic_1_loss: 0.0246 - val_semantic_2_loss: 0.0034 - lr: 5.8117e-05
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0399 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0198 - semantic_2_loss: 0.0026
# Epoch 00056: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0399 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0198 - semantic_2_loss: 0.0026 - val_loss: 0.0482 - val_semantic_0_loss: 0.0204 - val_semantic_1_loss: 0.0244 - val_semantic_2_loss: 0.0034 - lr: 5.7535e-05
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0347 - semantic_0_loss: 0.0145 - semantic_1_loss: 0.0176 - semantic_2_loss: 0.0025
# Epoch 00057: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0347 - semantic_0_loss: 0.0145 - semantic_1_loss: 0.0176 - semantic_2_loss: 0.0025 - val_loss: 0.0478 - val_semantic_0_loss: 0.0202 - val_semantic_1_loss: 0.0243 - val_semantic_2_loss: 0.0034 - lr: 5.6960e-05
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0424 - semantic_0_loss: 0.0173 - semantic_1_loss: 0.0224 - semantic_2_loss: 0.0028
# Epoch 00058: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0424 - semantic_0_loss: 0.0173 - semantic_1_loss: 0.0224 - semantic_2_loss: 0.0028 - val_loss: 0.0475 - val_semantic_0_loss: 0.0200 - val_semantic_1_loss: 0.0241 - val_semantic_2_loss: 0.0033 - lr: 5.6391e-05
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0425 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0221 - semantic_2_loss: 0.0030
# Epoch 00059: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0425 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0221 - semantic_2_loss: 0.0030 - val_loss: 0.0471 - val_semantic_0_loss: 0.0199 - val_semantic_1_loss: 0.0239 - val_semantic_2_loss: 0.0033 - lr: 5.5827e-05
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0364 - semantic_0_loss: 0.0143 - semantic_1_loss: 0.0196 - semantic_2_loss: 0.0025
# Epoch 00060: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0364 - semantic_0_loss: 0.0143 - semantic_1_loss: 0.0196 - semantic_2_loss: 0.0025 - val_loss: 0.0467 - val_semantic_0_loss: 0.0197 - val_semantic_1_loss: 0.0237 - val_semantic_2_loss: 0.0032 - lr: 5.5268e-05
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0422 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0221 - semantic_2_loss: 0.0027
# Epoch 00061: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0422 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0221 - semantic_2_loss: 0.0027 - val_loss: 0.0463 - val_semantic_0_loss: 0.0196 - val_semantic_1_loss: 0.0236 - val_semantic_2_loss: 0.0032 - lr: 5.4716e-05
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0476 - semantic_0_loss: 0.0187 - semantic_1_loss: 0.0258 - semantic_2_loss: 0.0031
# Epoch 00062: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0476 - semantic_0_loss: 0.0187 - semantic_1_loss: 0.0258 - semantic_2_loss: 0.0031 - val_loss: 0.0459 - val_semantic_0_loss: 0.0195 - val_semantic_1_loss: 0.0234 - val_semantic_2_loss: 0.0031 - lr: 5.4169e-05
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0325 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0168 - semantic_2_loss: 0.0024
# Epoch 00063: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0325 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0168 - semantic_2_loss: 0.0024 - val_loss: 0.0456 - val_semantic_0_loss: 0.0193 - val_semantic_1_loss: 0.0232 - val_semantic_2_loss: 0.0031 - lr: 5.3627e-05
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0396 - semantic_0_loss: 0.0165 - semantic_1_loss: 0.0205 - semantic_2_loss: 0.0027
# Epoch 00064: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0396 - semantic_0_loss: 0.0165 - semantic_1_loss: 0.0205 - semantic_2_loss: 0.0027 - val_loss: 0.0454 - val_semantic_0_loss: 0.0192 - val_semantic_1_loss: 0.0231 - val_semantic_2_loss: 0.0030 - lr: 5.3091e-05
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0316 - semantic_0_loss: 0.0129 - semantic_1_loss: 0.0164 - semantic_2_loss: 0.0023
# Epoch 00065: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0316 - semantic_0_loss: 0.0129 - semantic_1_loss: 0.0164 - semantic_2_loss: 0.0023 - val_loss: 0.0452 - val_semantic_0_loss: 0.0192 - val_semantic_1_loss: 0.0231 - val_semantic_2_loss: 0.0030 - lr: 5.2560e-05
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0322 - semantic_0_loss: 0.0134 - semantic_1_loss: 0.0165 - semantic_2_loss: 0.0023
# Epoch 00066: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0322 - semantic_0_loss: 0.0134 - semantic_1_loss: 0.0165 - semantic_2_loss: 0.0023 - val_loss: 0.0450 - val_semantic_0_loss: 0.0190 - val_semantic_1_loss: 0.0230 - val_semantic_2_loss: 0.0030 - lr: 5.2034e-05
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0516 - semantic_0_loss: 0.0202 - semantic_1_loss: 0.0282 - semantic_2_loss: 0.0033
# Epoch 00067: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0516 - semantic_0_loss: 0.0202 - semantic_1_loss: 0.0282 - semantic_2_loss: 0.0033 - val_loss: 0.0449 - val_semantic_0_loss: 0.0189 - val_semantic_1_loss: 0.0230 - val_semantic_2_loss: 0.0030 - lr: 5.1514e-05
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0388 - semantic_0_loss: 0.0158 - semantic_1_loss: 0.0205 - semantic_2_loss: 0.0025
# Epoch 00068: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0388 - semantic_0_loss: 0.0158 - semantic_1_loss: 0.0205 - semantic_2_loss: 0.0025 - val_loss: 0.0448 - val_semantic_0_loss: 0.0189 - val_semantic_1_loss: 0.0229 - val_semantic_2_loss: 0.0030 - lr: 5.0999e-05
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0448 - semantic_0_loss: 0.0178 - semantic_1_loss: 0.0243 - semantic_2_loss: 0.0028
# Epoch 00069: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0448 - semantic_0_loss: 0.0178 - semantic_1_loss: 0.0243 - semantic_2_loss: 0.0028 - val_loss: 0.0446 - val_semantic_0_loss: 0.0188 - val_semantic_1_loss: 0.0229 - val_semantic_2_loss: 0.0030 - lr: 5.0489e-05
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0498 - semantic_0_loss: 0.0197 - semantic_1_loss: 0.0270 - semantic_2_loss: 0.0032
# Epoch 00070: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0498 - semantic_0_loss: 0.0197 - semantic_1_loss: 0.0270 - semantic_2_loss: 0.0032 - val_loss: 0.0445 - val_semantic_0_loss: 0.0187 - val_semantic_1_loss: 0.0228 - val_semantic_2_loss: 0.0030 - lr: 4.9984e-05
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0432 - semantic_0_loss: 0.0181 - semantic_1_loss: 0.0223 - semantic_2_loss: 0.0027
# Epoch 00071: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0432 - semantic_0_loss: 0.0181 - semantic_1_loss: 0.0223 - semantic_2_loss: 0.0027 - val_loss: 0.0444 - val_semantic_0_loss: 0.0186 - val_semantic_1_loss: 0.0228 - val_semantic_2_loss: 0.0030 - lr: 4.9484e-05
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0392 - semantic_0_loss: 0.0162 - semantic_1_loss: 0.0204 - semantic_2_loss: 0.0027
# Epoch 00072: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0392 - semantic_0_loss: 0.0162 - semantic_1_loss: 0.0204 - semantic_2_loss: 0.0027 - val_loss: 0.0443 - val_semantic_0_loss: 0.0186 - val_semantic_1_loss: 0.0227 - val_semantic_2_loss: 0.0030 - lr: 4.8989e-05
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0373 - semantic_0_loss: 0.0156 - semantic_1_loss: 0.0192 - semantic_2_loss: 0.0025
# Epoch 00073: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0373 - semantic_0_loss: 0.0156 - semantic_1_loss: 0.0192 - semantic_2_loss: 0.0025 - val_loss: 0.0442 - val_semantic_0_loss: 0.0185 - val_semantic_1_loss: 0.0227 - val_semantic_2_loss: 0.0030 - lr: 4.8499e-05
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0506 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0271 - semantic_2_loss: 0.0032
# Epoch 00074: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0506 - semantic_0_loss: 0.0204 - semantic_1_loss: 0.0271 - semantic_2_loss: 0.0032 - val_loss: 0.0441 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0227 - val_semantic_2_loss: 0.0029 - lr: 4.8014e-05
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0443 - semantic_0_loss: 0.0178 - semantic_1_loss: 0.0237 - semantic_2_loss: 0.0028
# Epoch 00075: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0443 - semantic_0_loss: 0.0178 - semantic_1_loss: 0.0237 - semantic_2_loss: 0.0028 - val_loss: 0.0440 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0226 - val_semantic_2_loss: 0.0029 - lr: 4.7534e-05
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0461 - semantic_0_loss: 0.0177 - semantic_1_loss: 0.0256 - semantic_2_loss: 0.0028
# Epoch 00076: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0461 - semantic_0_loss: 0.0177 - semantic_1_loss: 0.0256 - semantic_2_loss: 0.0028 - val_loss: 0.0439 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0226 - val_semantic_2_loss: 0.0029 - lr: 4.7059e-05
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0412 - semantic_0_loss: 0.0170 - semantic_1_loss: 0.0216 - semantic_2_loss: 0.0026
# Epoch 00077: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0412 - semantic_0_loss: 0.0170 - semantic_1_loss: 0.0216 - semantic_2_loss: 0.0026 - val_loss: 0.0437 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0225 - val_semantic_2_loss: 0.0029 - lr: 4.6588e-05
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0458 - semantic_0_loss: 0.0179 - semantic_1_loss: 0.0248 - semantic_2_loss: 0.0030
# Epoch 00078: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0458 - semantic_0_loss: 0.0179 - semantic_1_loss: 0.0248 - semantic_2_loss: 0.0030 - val_loss: 0.0437 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0224 - val_semantic_2_loss: 0.0028 - lr: 4.6122e-05
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0390 - semantic_0_loss: 0.0163 - semantic_1_loss: 0.0201 - semantic_2_loss: 0.0026
# Epoch 00079: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0390 - semantic_0_loss: 0.0163 - semantic_1_loss: 0.0201 - semantic_2_loss: 0.0026 - val_loss: 0.0436 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0224 - val_semantic_2_loss: 0.0028 - lr: 4.5661e-05
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0417 - semantic_0_loss: 0.0167 - semantic_1_loss: 0.0222 - semantic_2_loss: 0.0028
# Epoch 00080: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0417 - semantic_0_loss: 0.0167 - semantic_1_loss: 0.0222 - semantic_2_loss: 0.0028 - val_loss: 0.0435 - val_semantic_0_loss: 0.0185 - val_semantic_1_loss: 0.0223 - val_semantic_2_loss: 0.0028 - lr: 4.5204e-05
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0409 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0216 - semantic_2_loss: 0.0027
# Epoch 00081: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0409 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0216 - semantic_2_loss: 0.0027 - val_loss: 0.0435 - val_semantic_0_loss: 0.0185 - val_semantic_1_loss: 0.0222 - val_semantic_2_loss: 0.0028 - lr: 4.4752e-05
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0432 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0231 - semantic_2_loss: 0.0027
# Epoch 00082: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0432 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0231 - semantic_2_loss: 0.0027 - val_loss: 0.0433 - val_semantic_0_loss: 0.0185 - val_semantic_1_loss: 0.0221 - val_semantic_2_loss: 0.0028 - lr: 4.4305e-05
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0471 - semantic_0_loss: 0.0195 - semantic_1_loss: 0.0248 - semantic_2_loss: 0.0029
# Epoch 00083: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0471 - semantic_0_loss: 0.0195 - semantic_1_loss: 0.0248 - semantic_2_loss: 0.0029 - val_loss: 0.0432 - val_semantic_0_loss: 0.0185 - val_semantic_1_loss: 0.0219 - val_semantic_2_loss: 0.0028 - lr: 4.3862e-05
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0336 - semantic_0_loss: 0.0144 - semantic_1_loss: 0.0169 - semantic_2_loss: 0.0023
# Epoch 00084: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 281ms/step - loss: 0.
val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0411 - semantic_0_loss: 0.0164 - semantic_1_loss: 0.0220 - semantic_2_loss: 0.0027 - val_loss: 0.0425 - val_semantic_0_loss: 0.0183 - val_semantic_1_loss: 0.0214 - val_semantic_2_loss: 0.0027 - lr: 4.0068e-05
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0334 - semantic_0_loss: 0.0141 - semantic_1_loss: 0.0170 - semantic_2_loss: 0.0023
# Epoch 00093: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0334 - semantic_0_loss: 0.0141 - semantic_1_loss: 0.0170 - semantic_2_loss: 0.0023 - val_loss: 0.0425 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0214 - val_semantic_2_loss: 0.0027 - lr: 3.9668e-05
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0423 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0222 - semantic_2_loss: 0.0027
# Epoch 00094: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0423 - semantic_0_loss: 0.0174 - semantic_1_loss: 0.0222 - semantic_2_loss: 0.0027 - val_loss: 0.0424 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0213 - val_semantic_2_loss: 0.0027 - lr: 3.9271e-05
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0389 - semantic_0_loss: 0.0160 - semantic_1_loss: 0.0203 - semantic_2_loss: 0.0026
# Epoch 00095: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0389 - semantic_0_loss: 0.0160 - semantic_1_loss: 0.0203 - semantic_2_loss: 0.0026 - val_loss: 0.0423 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0213 - val_semantic_2_loss: 0.0027 - lr: 3.8878e-05
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0482 - semantic_0_loss: 0.0195 - semantic_1_loss: 0.0258 - semantic_2_loss: 0.0029
# Epoch 00096: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0482 - semantic_0_loss: 0.0195 - semantic_1_loss: 0.0258 - semantic_2_loss: 0.0029 - val_loss: 0.0422 - val_semantic_0_loss: 0.0184 - val_semantic_1_loss: 0.0212 - val_semantic_2_loss: 0.0027 - lr: 3.8490e-05
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0418 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0226 - semantic_2_loss: 0.0026
# Epoch 00097: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0418 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0226 - semantic_2_loss: 0.0026 - val_loss: 0.0421 - val_semantic_0_loss: 0.0183 - val_semantic_1_loss: 0.0211 - val_semantic_2_loss: 0.0026 - lr: 3.8105e-05
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0330 - semantic_0_loss: 0.0141 - semantic_1_loss: 0.0167 - semantic_2_loss: 0.0022
# Epoch 00098: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0330 - semantic_0_loss: 0.0141 - semantic_1_loss: 0.0167 - semantic_2_loss: 0.0022 - val_loss: 0.0419 - val_semantic_0_loss: 0.0183 - val_semantic_1_loss: 0.0210 - val_semantic_2_loss: 0.0026 - lr: 3.7724e-05
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0410 - semantic_0_loss: 0.0169 - semantic_1_loss: 0.0215 - semantic_2_loss: 0.0026
# Epoch 00099: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0410 - semantic_0_loss: 0.0169 - semantic_1_loss: 0.0215 - semantic_2_loss: 0.0026 - val_loss: 0.0418 - val_semantic_0_loss: 0.0183 - val_semantic_1_loss: 0.0209 - val_semantic_2_loss: 0.0026 - lr: 3.7346e-05
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0335 - semantic_0_loss: 0.0137 - semantic_1_loss: 0.0175 - semantic_2_loss: 0.0023
# Epoch 00100: val_loss did not improve from 0.00474
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0335 - semantic_0_loss: 0.0137 - semantic_1_loss: 0.0175 - semantic_2_loss: 0.0023 - val_loss: 0.0417 - val_semantic_0_loss: 0.0182 - val_semantic_1_loss: 0.0209 - val_semantic_2_loss: 0.0026 - lr: 3.6973e-05
