# %% [markdown]
# **Train DeepCell Model with Cyto Images and Make Predictions**<br>
# It trains a model with three heads: inner distance, outer distance, and fgbg. It works on tensorflow 2.7.1.<br>
# Tissuenet V1.0 dataset is used, which has images of size 512x512 in the "Intro to DeepCell" are 256x256. In contrast, the pretrained model in NuclearApplication was trained on images of 512x512. There are 811165 training instances and 200770 validation instances.<br>
# Training can also be done via deepcell.training.train_model_sample, which allows arbitrary size images and uses window_size to control patch size.

# %%
import syotil

import numpy as np
from skimage import io
from matplotlib import pyplot as plt
# %matplotlib inline 
from timeit import default_timer

import tensorflow as tf
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.losses import MSE

import deepcell
from deepcell.utils.train_utils import rate_scheduler, get_callbacks, count_gpus
from deepcell.losses import weighted_categorical_crossentropy
from deepcell.model_zoo.panopticnet import PanopticNet
from deepcell_toolbox.deep_watershed import deep_watershed
from deepcell import image_generators

print(tf.__version__)
# Out:
# 2.7.1

# %%
label="cyto"
model_name = 'tn1.0_'+label; idx_X=1; idx_y=0
model_path = '{}.h5'.format(model_name)
epochs=60 # about 6 epochs/hr

# %%
train_dict = np.load('/fh/fast/fong_y/tissuenet_v1.0/tissuenet_v1.0_train.npz')
train_X, train_y = train_dict['X'], train_dict['y']

# # val is 256x256, thus not used
# val_dict = np.load('/fh/fast/fong_y/tissuenet_v1.0/tissuenet_v1.0_val.npz')
# X_val, y_val = val_dict['X'], val_dict['y']

# %%
seed = 0 
n=train_X.shape[0]

min_objects = 2

val_size = 0.2 # fraction of data saved as validation

import random
tmp = random.sample(range(n), int(val_size*n))

X_val = np.expand_dims(train_X[tmp,:,:,idx_X], axis=-1)
y_val = np.expand_dims(train_y[tmp,:,:,idx_y], axis=-1)

tmp1 = list(set(range(n)).difference (set(tmp)))
X_train = np.expand_dims(train_X[tmp1,:,:,idx_X], axis=-1)
y_train = np.expand_dims(train_y[tmp1,:,:,idx_y], axis=-1)

print('X_train.shape: {}\nX_val.shape: {}'.format(
    X_train.shape, X_val.shape))
transforms = ['inner-distance', 'outer-distance', 'fgbg']
transforms_kwargs = {'outer-distance': {'erosion_width': 0}}

# use augmentation for training but not validation
datagen = image_generators.SemanticDataGenerator(
    rotation_range=180,
    fill_mode='reflect',
    zoom_range=(0.75, 1.25),
    horizontal_flip=True,
    vertical_flip=True)

datagen_val = image_generators.SemanticDataGenerator()

batch_size = 4 # 8 causes memory outage

train_data = datagen.flow(
    {'X': X_train, 'y': y_train},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    {'X': X_val, 'y': y_val},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)
# Out:
# X_train.shape: (2081, 512, 512, 1)
# X_val.shape: (520, 512, 512, 1)

# %%
i=5
plt.subplot(1, 2, 1) # row 1, col 2 index 1
io.imshow(X_train[i,:,:,0])
plt.subplot(1, 2, 2) # row 1, col 2 index 1
# tmp = syotil.masks_to_outlines(y_train[i,:,:,0]); io.imshow(tmp)
io.imshow(y_train[i,:,:,0])
plt.show()
# Out:
# /app/software/scikit-image/0.19.1-foss-2021b/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# **Get Statistics on Training Data**

# %%
cnts_train = [np.max(y_train[i,...]) for i in range(y_train.shape[0])]
print(np.sum(cnts_train)) # total number of training instances

cnts_val = [np.max(y_val[i,...]) for i in range(y_val.shape[0])]
print(np.sum(cnts_val)) # total number of validation instance
# Out:
# 813655
# 198280

# %% [markdown]
# **The two cells below train the model and can be skipped if trained model will be loaded.**

# %%
semantic_classes = [1, 1, 2] # inner distance, outer distance, fgbg

model = PanopticNet(
    backbone='resnet50',
    input_shape=X_train.shape[1:],
    norm_method='whole_image',
    num_semantic_classes=semantic_classes)

lr = 1e-4
optimizer = Adam(lr=lr, clipnorm=0.001)
lr_sched = rate_scheduler(lr=lr, decay=0.99)

# Create a dictionary of losses for each semantic head

def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss

loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)
        
model.compile(loss=loss, optimizer=optimizer)

[(layer.name, layer.output_shape) for layer in filter(lambda x: x.name.startswith('semantic_'), model.layers)]
# Out:
# 2022-11-01 12:20:15.108591: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-11-01 12:20:18.589419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14657 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:04:00.0, compute capability: 7.0
# 2022-11-01 12:20:18.590737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14657 MB memory:  -> device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:06:00.0, compute capability: 7.0
# 2022-11-01 12:20:18.591896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 14657 MB memory:  -> device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 0000:08:00.0, compute capability: 7.0
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [('semantic_0', (None, 512, 512, 1)),
#  ('semantic_1', (None, 512, 512, 1)),
#  ('semantic_2', (None, 512, 512, 2))]

# %%
# fit the model
print('Training on', count_gpus(), 'GPUs.')

train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    monitor='val_loss',
    verbose=1)

loss_history = model.fit(
    train_data,
    steps_per_epoch=train_data.y.shape[0] // batch_size,
    epochs=epochs, 
    validation_data=val_data,
    validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
# Out:
# 2022-11-01 12:20:24.854852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 14657 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:04:00.0, compute capability: 7.0
# 2022-11-01 12:20:24.855763: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:1 with 14657 MB memory:  -> device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:06:00.0, compute capability: 7.0
# 2022-11-01 12:20:24.856666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:2 with 14657 MB memory:  -> device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 0000:08:00.0, compute capability: 7.0
# Training on 3 GPUs.
# Epoch 1/2
# 2022-11-01 12:20:41.194298: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8202
# 520/520 [==============================] - ETA: 0s - loss: 0.1196 - semantic_0_loss: 0.0339 - semantic_1_loss: 0.0807 - semantic_2_loss: 0.0049
# Epoch 00001: val_loss improved from inf to 0.14319, saving model to tn1.0_cyto.h5
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 520/520 [==============================] - 681s 1s/step - loss: 0.1196 - semantic_0_loss: 0.0339 - semantic_1_loss: 0.0807 - semantic_2_loss: 0.0049 - val_loss: 0.1432 - val_semantic_0_loss: 0.0267 - val_semantic_1_loss: 0.1055 - val_semantic_2_loss: 0.0109 - lr: 1.0000e-04
# Epoch 2/2
# 520/520 [==============================] - ETA: 0s - loss: 0.0889 - semantic_0_loss: 0.0218 - semantic_1_loss: 0.0626 - semantic_2_loss: 0.0045
# Epoch 00002: val_loss improved from 0.14319 to 0.08987, saving model to tn1.0_cyto.h5
# 520/520 [==============================] - 654s 1s/step - loss: 0.0889 - semantic_0_loss: 0.0218 - semantic_1_loss: 0.0626 - semantic_2_loss: 0.0045 - val_loss: 0.0899 - val_semantic_0_loss: 0.0224 - val_semantic_1_loss: 0.0625 - val_semantic_2_loss: 0.0049 - lr: 9.9000e-05

# %% [markdown]
# <B>Make Predictions on Validation Dataset</B>

# %%
prediction_model = PanopticNet(
    backbone='resnet50',
    norm_method='whole_image',
    num_semantic_classes=[1, 1], # inner distance, outer distance
    input_shape= X_val.shape[1:]
)

prediction_model.load_weights(model_path, by_name=True)
# Out:
# 2022-11-02 09:54:12.843960: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-11-02 09:54:18.153507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14657 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:04:00.0, compute capability: 7.0
# 2022-11-02 09:54:18.161918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14657 MB memory:  -> device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:06:00.0, compute capability: 7.0
# 2022-11-02 09:54:18.163102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 14657 MB memory:  -> device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 0000:08:00.0, compute capability: 7.0

# %%
# make predictions on validation data

# insufficient memory error!

start = default_timer()
test_images = prediction_model.predict(X_val)
watershed_time = default_timer() - start

# print('Watershed segmentation of shape', test_images[0].shape, 'in', watershed_time, 'seconds.')

masks = deep_watershed(
    test_images,
    min_distance=10,
    detection_threshold=0.1,
    distance_threshold=0.01,
    exclude_border=False,
    small_objects_threshold=0)
# Out:
# 2022-11-01 12:42:49.753514: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-11-01 12:42:49.753562: W tensorflow/core/kernels/gpu_utils.cc:49] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2022-11-01 12:42:59.935485: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.00GiB (rounded to 4294967296)requested by op panopticnet/batch_normalization_0_semantic_1/FusedBatchNormV3
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-11-01 12:42:59.935670: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2022-11-01 12:42:59.935720: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 283, Chunks in use: 283. 70.8KiB allocated for chunks. 70.8KiB in use in bin. 45.6KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935749: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 220, Chunks in use: 219. 110.5KiB allocated for chunks. 110.0KiB in use in bin. 109.5KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935774: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 364, Chunks in use: 364. 368.8KiB allocated for chunks. 368.8KiB in use in bin. 364.0KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935799: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 231, Chunks in use: 231. 478.5KiB allocated for chunks. 478.5KiB in use in bin. 462.0KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935823: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 147, Chunks in use: 147. 616.0KiB allocated for chunks. 616.0KiB in use in bin. 588.0KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935848: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 85, Chunks in use: 85. 722.2KiB allocated for chunks. 722.2KiB in use in bin. 686.5KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935874: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 7, Chunks in use: 6. 122.8KiB allocated for chunks. 103.8KiB in use in bin. 94.5KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935899: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 16, Chunks in use: 16. 587.2KiB allocated for chunks. 587.2KiB in use in bin. 535.8KiB client-requested in use in bin.
# 2022-11-01 12:42:59.935922: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 32, Chunks in use: 30. 2.10MiB allocated for chunks. 1.95MiB in use in bin. 1.88MiB client-requested in use in bin.
# 2022-11-01 12:42:59.935945: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 39, Chunks in use: 39. 5.64MiB allocated for chunks. 5.64MiB in use in bin. 5.41MiB client-requested in use in bin.
# 2022-11-01 12:42:59.935969: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 39, Chunks in use: 38. 10.63MiB allocated for chunks. 10.37MiB in use in bin. 9.17MiB client-requested in use in bin.
# 2022-11-01 12:42:59.935994: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 41, Chunks in use: 40. 23.77MiB allocated for chunks. 23.27MiB in use in bin. 21.62MiB client-requested in use in bin.
# 2022-11-01 12:42:59.936019: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 65, Chunks in use: 64. 67.62MiB allocated for chunks. 66.19MiB in use in bin. 61.81MiB client-requested in use in bin.
# 2022-11-01 12:42:59.936044: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 51, Chunks in use: 50. 124.69MiB allocated for chunks. 122.44MiB in use in bin. 109.00MiB client-requested in use in bin.
# 2022-11-01 12:42:59.936069: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 30, Chunks in use: 29. 139.29MiB allocated for chunks. 131.79MiB in use in bin. 109.00MiB client-requested in use in bin.
# 2022-11-01 12:42:59.936095: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 22, Chunks in use: 20. 217.88MiB allocated for chunks. 192.00MiB in use in bin. 175.00MiB client-requested in use in bin.
# 2022-11-01 12:42:59.936119: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 36.00MiB allocated for chunks. 36.00MiB in use in bin. 36.00MiB client-requested in use in bin.
# 2022-11-01 12:42:59.936143: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-01 12:42:59.936167: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-01 12:42:59.936188: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-01 12:42:59.936211: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 6, Chunks in use: 3. 13.70GiB allocated for chunks. 8.51GiB in use in bin. 8.51GiB client-requested in use in bin.
# 2022-11-01 12:42:59.936242: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 4.00GiB was 256.00MiB, Chunk State:
# 2022-11-01 12:42:59.936277: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 1.00GiB | Requested Size: 2.00GiB | in_use: 0 | bin_num: 20, prev:   Size: 4.00GiB | Requested Size: 4.00GiB | in_use: 1 | bin_num: -1, next:   Size: 4.00GiB | Requested Size: 4.00GiB | in_use: 1 | bin_num: -1
# 2022-11-01 12:42:59.936307: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 2.00GiB | Requested Size: 2.00GiB | in_use: 0 | bin_num: 20, prev:   Size: 520.00MiB | Requested Size: 520.00MiB | in_use: 1 | bin_num: -1, next:   Size: 4.00GiB | Requested Size: 4.00GiB | in_use: 1 | bin_num: -1
# 2022-11-01 12:42:59.936331: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 2.19GiB | Requested Size: 2.02GiB | in_use: 0 | bin_num: 20, prev:   Size: 4.00GiB | Requested Size: 4.00GiB | in_use: 1 | bin_num: -1
# 2022-11-01 12:42:59.936351: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 15369502720
# 2022-11-01 12:42:59.936374: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000000 of size 1280 next 1
# 2022-11-01 12:42:59.936394: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000500 of size 256 next 2
# 2022-11-01 12:42:59.936414: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000600 of size 256 next 3
# 2022-11-01 12:42:59.936433: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000700 of size 256 next 6
# 2022-11-01 12:42:59.936451: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000800 of size 256 next 7
# 2022-11-01 12:42:59.936470: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000900 of size 256 next 8
# 2022-11-01 12:42:59.936488: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000a00 of size 256 next 9
# 2022-11-01 12:42:59.936507: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000b00 of size 256 next 10
# 2022-11-01 12:42:59.936526: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000c00 of size 256 next 11
# 2022-11-01 12:42:59.936544: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000d00 of size 256 next 12
# 2022-11-01 12:42:59.936563: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000e00 of size 256 next 15
# 2022-11-01 12:42:59.936581: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02000f00 of size 256 next 219
# 2022-11-01 12:42:59.936600: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02
I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a02073600 of size 98304 next 41
# 2022-11-01 12:42:59.941169: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a0208b600 of size 147456 next 40
# 2022-11-01 12:42:59.941188: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020af600 of size 65536 next 70
# 2022-11-01 12:42:59.941206: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020bf600 of size 2048 next 331
# 2022-11-01 12:42:59.941225: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020bfe00 of size 2048 next 332
# 2022-11-01 12:42:59.941243: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c0600 of size 1024 next 54
# 2022-11-01 12:42:59.941262: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c0a00 of size 3072 next 335
# 2022-11-01 12:42:59.941280: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c1600 of size 2048 next 336
# 2022-11-01 12:42:59.941298: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c1e00 of size 2048 next 337
# 2022-11-01 12:42:59.941317: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c2600 of size 2048 next 338
# 2022-11-01 12:42:59.941335: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c2e00 of size 2048 next 1301
# 2022-11-01 12:42:59.941353: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c3600 of size 1024 next 34
# 2022-11-01 12:42:59.941372: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c3a00 of size 1024 next 342
# 2022-11-01 12:42:59.941391: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c3e00 of size 10240 next 344
# 2022-11-01 12:42:59.941410: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c6600 of size 8192 next 345
# 2022-11-01 12:42:59.941430: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020c8600 of size 8192 next 347
# 2022-11-01 12:42:59.941448: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020ca600 of size 3072 next 653
# 2022-11-01 12:42:59.941467: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cb200 of size 1024 next 595
# 2022-11-01 12:42:59.941485: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cb600 of size 2048 next 537
# 2022-11-01 12:42:59.941504: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cbe00 of size 4096 next 231
# 2022-11-01 12:42:59.941523: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cce00 of size 512 next 279
# 2022-11-01 12:42:59.941541: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cd000 of size 512 next 1293
# 2022-11-01 12:42:59.941560: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cd200 of size 512 next 568
# 2022-11-01 12:42:59.941578: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cd400 of size 2560 next 199
# 2022-11-01 12:42:59.941597: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cde00 of size 2048 next 349
# 2022-11-01 12:42:59.941616: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020ce600 of size 2048 next 303
# 2022-11-01 12:42:59.941634: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cee00 of size 2048 next 350
# 2022-11-01 12:42:59.941652: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cf600 of size 2048 next 352
# 2022-11-01 12:42:59.941671: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020cfe00 of size 1024 next 683
# 2022-11-01 12:42:59.941690: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0200 of size 512 next 665
# 2022-11-01 12:42:59.941708: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0400 of size 512 next 16
# 2022-11-01 12:42:59.941727: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0600 of size 512 next 1277
# 2022-11-01 12:42:59.941745: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0800 of size 512 next 614
# 2022-11-01 12:42:59.941764: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0a00 of size 512 next 660
# 2022-11-01 12:42:59.941782: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0c00 of size 512 next 354
# 2022-11-01 12:42:59.941801: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d0e00 of size 2048 next 309
# 2022-11-01 12:42:59.941819: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d1600 of size 2048 next 356
# 2022-11-01 12:42:59.941838: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d1e00 of size 2048 next 359
# 2022-11-01 12:42:59.941856: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d2600 of size 1024 next 486
# 2022-11-01 12:42:59.941874: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d2a00 of size 1024 next 628
# 2022-11-01 12:42:59.941893: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d2e00 of size 2048 next 361
# 2022-11-01 12:42:59.941911: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d3600 of size 8192 next 363
# 2022-11-01 12:42:59.941929: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d5600 of size 8192 next 365
# 2022-11-01 12:42:59.941949: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d7600 of size 8192 next 366
# 2022-11-01 12:42:59.941967: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d9600 of size 2048 next 553
# 2022-11-01 12:42:59.941986: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020d9e00 of size 2048 next 559
# 2022-11-01 12:42:59.942004: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a020da600 of size 3072 next 510
# 2022-11-01 12:42:59.942023: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6a
I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7602176 totalling 7.25MiB
# 2022-11-01 12:43:00.036353: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 8388608 totalling 16.00MiB
# 2022-11-01 12:43:00.036371: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 14 Chunks of size 9437184 totalling 126.00MiB
# 2022-11-01 12:43:00.036388: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 10485760 totalling 10.00MiB
# 2022-11-01 12:43:00.036405: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12582912 totalling 12.00MiB
# 2022-11-01 12:43:00.036422: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 14680064 totalling 28.00MiB
# 2022-11-01 12:43:00.036439: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 18874368 totalling 36.00MiB
# 2022-11-01 12:43:00.036457: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 545259520 totalling 520.00MiB
# 2022-11-01 12:43:00.036474: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 4294967296 totalling 8.00GiB
# 2022-11-01 12:43:00.036491: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 9.09GiB
# 2022-11-01 12:43:00.036507: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 15369502720 memory_limit_: 15369502720 available bytes: 0 curr_region_allocation_bytes_: 30739005440
# 2022-11-01 12:43:00.036529: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                     15369502720
# InUse:                      9756613888
# MaxInUse:                  12743501568
# NumAllocs:                     2770103
# MaxAllocSize:               4294967296
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-11-01 12:43:00.036655: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ********_____________*****************************______*****************************_______________
# 2022-11-01 12:43:00.036738: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at fused_batch_norm_op.cc:1379 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,128,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_5326/1693405542.py in <module>
#       4
#       5 start = default_timer()
# ----> 6 test_images = prediction_model.predict(X_val)
#       7 watershed_time = default_timer() - start
#       8
#
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[32,128,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node panopticnet/batch_normalization_0_semantic_1/FusedBatchNormV3
#  (defined at /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py:605)
# ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_predict_function_52740]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node panopticnet/batch_normalization_0_semantic_1/FusedBatchNormV3:
# In[0] panopticnet/conv_0_semantic_1/BiasAdd (defined at /app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/layers/convolutional.py:264)
# In[1] panopticnet/batch_normalization_0_semantic_1/ReadVariableOp:
# In[2] panopticnet/batch_normalization_0_semantic_1/ReadVariableOp_1:
# In[3] panopticnet/batch_normalization_0_semantic_1/FusedBatchNormV3/ReadVariableOp:
# In[4] panopticnet/batch_normalization_0_semantic_1/FusedBatchNormV3/ReadVariableOp_1:
#
# Operation defined at: (most recent call last)
# >>>   File "/app/software/Python/3.9.6-GCCcore-11.2.0/lib/python3.9/runpy.py", line 197, in _run_module_as_main
# >>>     return _run_code(code, main_globals, None,
# >>>
# >>>   File "/app/software/Python/3.9.6-GCCcore-11.2.0/lib/python3.9/runpy.py", line 87, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/traitlets/config/application.py", line 845, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 667, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "/app/software/bokeh/2.4.2-foss-2021b/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "/app/software/Python/3.9.6-GCCcore-11.2.0/lib/python3.9/asyncio/base_events.py", line 596, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "/app/software/Python/3.9.6-GCCcore-11.2.0/lib/python3.9/asyncio/base_events.py", line 1890, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "/app/software/Python/3.9.6-GCCcore-11.2.0/lib/python3.9/asyncio/events.py", line 80, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 445, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 345, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
# >>>     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
# >>>     result = self._run_cell(
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
# >>>     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "/app/software/IPython/7.26.0-GCCcore-11.2.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "/tmp/ipykernel_5326/1693405542.py", line 6, in <module>
# >>>     test_images = prediction_model.predict(X_val)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/training.py", line 1789, in predict
# >>>     tmp_batch_outputs = self.predict_function(iterator)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/training.py", line 1621, in predict_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/training.py", line 1611, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/training.py", line 1604, in run_step
# >>>     outputs = model.predict_step(data)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/training.py", line 1572, in predict_step
# >>>     return self(x, training=False)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/functional.py", line 451, in call
# >>>     return self._run_internal_graph(
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py", line 767, in call
# >>>     outputs = self._fused_batch_norm(inputs, training=training)
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py", line 623, in _fused_batch_norm
# >>>     output, mean, variance = control_flow_util.smart_cond(
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/utils/control_flow_util.py", line 105, in smart_cond
# >>>     return tf.__internal__.smart_cond.smart_cond(
# >>>
# >>>   File "/app/software/TensorFlow/2.7.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py", line 605, in _fused_batch_norm_inference
# >>>     return tf.compat.v1.nn.fused_batch_norm(
# >>>

# %%
io.imshow(X_val[1,:,:,0])
plt.show()
io.imshow(y_val[1,:,:,0])
plt.show()
print(X_val.shape)
print(y_val.shape)
# Out:
# (520, 512, 512, 1)
# (520, 512, 512, 1)

# %%
APs = [syotil.csi(y_val[i,:,:,0], masks[i,:,:,0]) for i in range(y_val.shape[0])]
print(np.nanmean(APs))

# %% [markdown]
# **Make prediction on K's data.**<br>
# Using NuclearSegmentation allows setting image_mpp, which has a substantial influence on performance.

# %%
from deepcell.applications import NuclearSegmentation
app = NuclearSegmentation(prediction_model)
[(layer.name, layer.output_shape) for layer in filter(lambda x: x.name.startswith('semantic_'), app.model.layers)]
# Out:
# [('semantic_0', (None, 512, 512, 1)), ('semantic_1', (None, 512, 512, 1))]

# %%
import os
print(os.getcwd())
INPUT_PATH="images/test/"
FILENAMES = [f for f in os.listdir("images/training/testimages")]
print(FILENAMES)
# Out:
# /home/yfong/deeplearning/dense_cell_segmentation
# ['M926910_CFL_Position7_CD3_test_img.png', 'M872956_JML_Position10_CD3_test_img.png', 'M872956_JML_Position8_CD8_test_img.png', 'M926910_CFL_Position13_CD3_test_img.png', 'M872956_JML_Position8_CD3_test_img.png', 'M872956_JML_Position8_CD4_test_img.png', 'M872956_JML_Position9_CD3_test_img.png']

# %%
APs={}
for CURR_IM_NAME in FILENAMES:
    im0 = io.imread(os.path.join(INPUT_PATH, CURR_IM_NAME))
    mask_true=io.imread(os.path.join(INPUT_PATH, CURR_IM_NAME.replace("img","masks")))

    x = np.expand_dims(im0, axis=-1)
    x = np.expand_dims(x, axis=0)
    y, tile_info = app._tile_input(x)
    print(x.shape)
    print(y.shape)
    print(tile_info)
    pred = app.predict(y, image_mpp=1)
    prd = app._untile_output(pred, tile_info)
    #io.imshow(prd[0,:,:,0])
    plt.show()
    
    APs[CURR_IM_NAME] = syotil.csi(mask_true, prd[0,:,:,0])# masks may lose one pixel if dimension is odd pixels

APs["mAP"]=np.mean(list(APs.values()))
# print(APs)
# Out:
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}
# /app/software/DeepCell/0.11.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0.Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}
# (1, 1040, 233, 1)
# (1, 1568, 512, 1)
# {'padding': True, 'x_pad': (264, 264), 'y_pad': (139, 140)}

# %%
import pandas as pd
df = pd.DataFrame([FILENAMES+["mAP"], list(APs.values())])
print(df.transpose())
df.to_csv('images/training/csi_tn_'+label+'.txt', index=False, header=False)
# Out:
#                                          0         1
# 0   M926910_CFL_Position7_CD3_test_img.png  0.067919
# 1  M872956_JML_Position10_CD3_test_img.png  0.067657
# 2   M872956_JML_Position8_CD8_test_img.png  0.132743
# 3  M926910_CFL_Position13_CD3_test_img.png  0.054374
# 4   M872956_JML_Position8_CD3_test_img.png  0.057276
# 5   M872956_JML_Position8_CD4_test_img.png  0.132898
# 6   M872956_JML_Position9_CD3_test_img.png  0.068966
# 7                                      mAP  0.083119

# %% [markdown]
# **mAP after 60 epochs**<br>
# image_mpp=1: .08<br>
# image_mpp=2: .14<br>
# image_mpp=3: .08<br>

# %%
# more detailed mapping of image_mpp parameter
AP_mat=[]
for CURR_IM_NAME in FILENAMES:
    print(CURR_IM_NAME)
    im0 = io.imread(os.path.join(INPUT_PATH, CURR_IM_NAME))
    mask_true=io.imread(os.path.join(INPUT_PATH, CURR_IM_NAME.replace("img","masks")))

    x = np.expand_dims(im0, axis=-1)
    x = np.expand_dims(x, axis=0)
    y, tile_info = app._tile_input(x)
    AP_arr=[]
    for mpp in np.linspace(start=1.0, stop=2.8, num=10):
        prd = app._untile_output(app.predict(y, image_mpp=mpp), tile_info)[0,:,:,0]
        a=syotil.csi(mask_true, prd)
        AP_arr.append(a)
    AP_mat.append(AP_arr)
#AP_mat
# Out:
# M926910_CFL_Position7_CD3_test_img.png
# /app/software/DeepCell/0.11.1-foss-2021b-CUDA-11.4.1/lib/python3.9/site-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0.Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# M872956_JML_Position10_CD3_test_img.png
# M872956_JML_Position8_CD8_test_img.png
# M926910_CFL_Position13_CD3_test_img.png
# M872956_JML_Position8_CD3_test_img.png
# M872956_JML_Position8_CD4_test_img.png
# M872956_JML_Position9_CD3_test_img.png

# %%
[x.index(np.max(x)) for x in AP_mat]
# Out:
# [3, 4, 3, 5, 5, 2, 4]

# %%
np.linspace(start=1,stop=2.8,num=10)
# Out:
# array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8])

# %% [markdown]
# 2 seems best.
